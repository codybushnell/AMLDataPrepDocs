# %% [markdown]
# # Data Ingestion
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %%
import azureml.dataprep as dprep

# %% [markdown]
# Data Prep has the ability to load different types of input data. You can use auto-reading functionality to detect the type of a file, or directly specify a file type and its parameters.

# %% [markdown]
# ## Table of Contents
# [Read Lines](#Read-Lines)<br>
# [Read CSV](#Read-CSV)<br>
# [Read Compressed CSV](#Read-Compressed-CSV)<br>
# [Read Excel](#Read-Excel)<br>
# [Read Fixed Width Files](#Read-Fixed-Width-Files)<br>
# [Read Parquet](#Read-Parquet)<br>
# [Read JSON](#Read-JSON)<br>
# [Read SQL](#Read-SQL)<br>
# [Read From ADLS](#Read-From-ADLS)<br>
# [Read Pandas DataFrame](#Read-Pandas-DataFrame)<br>

# %% [markdown]
# ## Read Lines

# %% [markdown]
# One of the simplest ways to read data using Data Prep is to just read it as text lines.

# %%
dflow = dprep.read_lines(path='../data/crime.txt')
dflow.head(5)
# Out:
#                                                 Line
# 0  10140490 HY329907 7/5/2015  23:50             ...
# 1  10139776 HY329265 7/5/2015  23:30             ...
# 2  10140270 HY329253 7/5/2015  23:20             ...
# 3  10139885 HY329308 7/5/2015  23:19             ...
# 4  10140379 HY329556 7/5/2015  23:00             ...

# %% [markdown]
# With ingestion done, you can go ahead and start prepping the dataset.

# %%
df = dflow.to_pandas_dataframe()
df
# Out:
#                                                 Line
# 0  10140490 HY329907 7/5/2015  23:50             ...
# 1  10139776 HY329265 7/5/2015  23:30             ...
# 2  10140270 HY329253 7/5/2015  23:20             ...
# 3  10139885 HY329308 7/5/2015  23:19             ...
# 4  10140379 HY329556 7/5/2015  23:00             ...
# 5  10140868 HY330421 7/5/2015  22:54             ...
# 6  10139762 HY329232 7/5/2015  22:42             ...
# 7  10139722 HY329228 7/5/2015  22:30             ...
# 8  10139774 HY329209 7/5/2015  22:15             ...
# 9  10139697 HY329177 7/5/2015  22:10             ...

# %% [markdown]
# ## Read CSV

# %% [markdown]
# When reading delimited files, you can let the underlying runtime infer the parsing parameters (e.g. separator, encoding, whether to use headers, etc.) simply by not providing them. In this case, you can read a file by specifying only its location, then retrieve the first 10 rows to evaluate the result.

# %%
dflow_duplicate_headers = dprep.read_csv(path='../data/crime_duplicate_headers.csv')
dflow_duplicate_headers.head(5)
# Out:
#          ID  Case Number             Date                   Block  IUCR  \
# 0        ID  Case Number             Date                   Block  IUCR
# 1  10498554     HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 2  10516598     HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 3  10519196     HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 4  10519591     HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
#
#          Primary Type                              Description  \
# 0        Primary Type                              Description
# 1  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2               THEFT                            FROM BUILDING
# 3  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4  DECEPTIVE PRACTICE                                  FORGERY
#
#    Location Description  Arrest  Domestic              ...                \
# 0  Location Description  Arrest  Domestic              ...
# 1                 OTHER   FALSE     FALSE              ...
# 2             RESIDENCE   FALSE     FALSE              ...
# 3             RESIDENCE   FALSE     FALSE              ...
# 4             RESIDENCE   FALSE     FALSE              ...
#
#    Ward  Community Area  FBI Code  X Coordinate  Y Coordinate  Year  \
# 0  Ward  Community Area  FBI Code  X Coordinate  Y Coordinate  Year
# 1     9              50        11       1183356       1831503  2016
# 2    21              71         6       1166776       1850053  2016
# 3    19              74        11                              2016
# 4     9              49        10                              2016
#
#         Updated On     Latitude     Longitude                       Location
# 0       Updated On     Latitude     Longitude                       Location
# 1  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 2  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 3  5/12/2016 15:50
# 4  5/13/2016 15:51
#
# [5 rows x 22 columns]

# %% [markdown]
# From the result, you can see that the delimiter and encoding were correctly detected. Column headers were also detected. However, the first line seems to be a duplicate of the column headers. One of the parameters is a number of lines to skip from the files being read. You can use this to filter out the duplicate line.

# %%
dflow_skip_headers = dprep.read_csv(path='../data/crime_duplicate_headers.csv', skip_rows=1)
dflow_skip_headers.head(5)
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# Now the data set contains the correct headers and the extraneous row has been skipped by read_csv. Next, look at the data types of the columns.

# %%
dflow_skip_headers.dtypes
# Out:
# ID                       FieldType.STRING
# Block                    FieldType.STRING
# Community Area           FieldType.STRING
# IUCR                     FieldType.STRING
# Year                     FieldType.STRING
# Date                     FieldType.STRING
# Arrest                   FieldType.STRING
# Updated On               FieldType.STRING
# Latitude                 FieldType.STRING
# Case Number              FieldType.STRING
# Beat                     FieldType.STRING
# Ward                     FieldType.STRING
# Longitude                FieldType.STRING
# Location Description     FieldType.STRING
# Y Coordinate             FieldType.STRING
# Description              FieldType.STRING
# FBI Code                 FieldType.STRING
# Primary Type             FieldType.STRING
# District                 FieldType.STRING
# Domestic                 FieldType.STRING
# X Coordinate             FieldType.STRING
# Location                 FieldType.STRING

# %% [markdown]
# Unfortunately, all of the columns came back as strings. This is because, by default, Data Prep will not change the type of the data. Since the data source is a text file, all values are kept as strings. In this case, however, numeric columns should be parsed as numbers. To do this, set the `inference_arguments` parameter to a new instance of the `InferenceArguments` class, which will trigger type inference to be performed.
# Note that setting inference arguments at this step also requires you to choose a strategy for dealing with ambiguous dates. The example below shows the month before day option.

# %%
dflow_inferred_types = dprep.read_csv(path='../data/crime_duplicate_headers.csv',
                          skip_rows=1,
                          inference_arguments=dprep.InferenceArguments(day_first=False))
dflow_inferred_types.dtypes
# Out:
# ID                       FieldType.DECIMAL
# Block                    FieldType.STRING
# Community Area           FieldType.DECIMAL
# IUCR                     FieldType.DECIMAL
# Year                     FieldType.DECIMAL
# Date                     FieldType.DATE
# Arrest                   FieldType.BOOLEAN
# Updated On               FieldType.DATE
# Latitude                 FieldType.DECIMAL
# Case Number              FieldType.STRING
# Beat                     FieldType.DECIMAL
# Ward                     FieldType.DECIMAL
# Longitude                FieldType.DECIMAL
# Location Description     FieldType.STRING
# Y Coordinate             FieldType.DECIMAL
# Description              FieldType.STRING
# FBI Code                 FieldType.DECIMAL
# Primary Type             FieldType.STRING
# District                 FieldType.DECIMAL
# Domestic                 FieldType.BOOLEAN
# X Coordinate             FieldType.DECIMAL
# Location                 FieldType.STRING

# %% [markdown]
# Now several of the columns were correctly detected as numbers and their `FieldType` is Decimal.
#
# With ingestion done, the data set is ready to start preparing.

# %%
df = dflow_inferred_types.to_pandas_dataframe()
df
# Out:
#            ID Case Number                Date                   Block    IUCR  \
# 0  10498554.0    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598.0    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196.0    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591.0    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446.0    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
# 5  10535059.0    HZ278872 2016-04-15 04:30:00    004XX S KILBOURN AVE   810.0
# 6  10499802.0    HZ240778 2016-04-15 10:00:00   010XX N MILWAUKEE AVE  1152.0
# 7  10522293.0    HZ264802 2016-04-15 16:00:00     019XX W DIVISION ST  1110.0
# 8  10523111.0    HZ265911 2016-04-15 08:00:00     061XX N SHERIDAN RD  1153.0
# 9  10525877.0    HZ268138 2016-04-15 15:00:00    023XX W EASTWOOD AVE  1153.0
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
# 5               THEFT                                OVER $500
# 6  DECEPTIVE PRACTICE                    ILLEGAL USE CASH CARD
# 7  DECEPTIVE PRACTICE                              BOGUS CHECK
# 8  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 9  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  False    False              ...
# 1                 RESIDENCE  False    False              ...
# 2                 RESIDENCE  False    False              ...
# 3                 RESIDENCE  False    False              ...
# 4  SCHOOL, PUBLIC, BUILDING  False    False              ...
# 5                 RESIDENCE  False    False              ...
# 6                 RESIDENCE  False    False              ...
# 7                RESTAURANT  False    False              ...
# 8                 RESIDENCE  False    False              ...
# 9                            False    False              ...
#
#    Ward  Community Area  FBI Code  X Coordinate  Y Coordinate    Year  \
# 0   9.0            50.0      11.0     1183356.0     1831503.0  2016.0
# 1  21.0            71.0       6.0     1166776.0     1850053.0  2016.0
# 2  19.0            74.0      11.0           NaN           NaN  2016.0
# 3   9.0            49.0      10.0           NaN           NaN  2016.0
# 4  40.0            13.0       6.0           NaN           NaN  2016.0
# 5  24.0            26.0       6.0           NaN           NaN  2016.0
# 6  27.0            24.0      11.0           NaN           NaN  2016.0
# 7   1.0            24.0      11.0     1163094.0     1908003.0  2016.0
# 8  48.0            77.0      11.0           NaN           NaN  2016.0
# 9  47.0             4.0      11.0           NaN           NaN  2016.0
#
#            Updated On   Latitude  Longitude                       Location
# 0 2016-05-11 15:48:00  41.692834 -87.604319   (41.692833841, -87.60431945)
# 1 2016-05-12 15:48:00  41.744107 -87.664494  (41.744106973, -87.664494285)
# 2 2016-05-12 15:50:00        NaN        NaN
# 3 2016-05-13 15:51:00        NaN        NaN
# 4 2016-05-25 15:59:00        NaN        NaN
# 5 2016-05-25 15:59:00        NaN        NaN
# 6 2016-05-27 15:45:00        NaN        NaN
# 7 2016-05-16 15:48:00  41.903206 -87.676362  (41.903206037, -87.676361925)
# 8 2016-05-16 15:50:00        NaN        NaN
# 9 2016-05-18 15:50:00        NaN        NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Read Compressed CSV

# %% [markdown]
# Data Prep can also read delimited files compressed in an archive. The `archive_options` parameter specifies the type of archive and glob pattern of entries in the archive.
#
# At this moment, only reading from ZIP archives is supported.

# %%
from azureml.dataprep import ArchiveOptions, ArchiveType

dflow = dprep.read_csv(path='../data/crime.zip',
                          archive_options=ArchiveOptions(archive_type=ArchiveType.ZIP, entry_glob='*10-20.csv'))
dflow.head(5)
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10140342    HY329728  07/05/2015 10:00:00 PM    050XX W BALMORAL AVE  0820
# 1  10140280    HY329658  07/05/2015 10:00:00 PM  007XX S CALIFORNIA AVE  0810
# 2  10139771    HY329216  07/05/2015 10:00:00 PM  077XX S WINCHESTER AVE  0560
# 3  10142577    HY331987  07/05/2015 10:00:00 PM   025XX N NEWCASTLE AVE  0930
# 4  10141300    HY330294  07/05/2015 09:30:00 PM      007XX N SAWYER AVE  0486
#
#           Primary Type                 Description     Location Description  \
# 0                THEFT              $500 AND UNDER  RESIDENCE PORCH/HALLWAY
# 1                THEFT                   OVER $500                   STREET
# 2              ASSAULT                      SIMPLE  RESIDENCE PORCH/HALLWAY
# 3  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE                   STREET
# 4              BATTERY     DOMESTIC BATTERY SIMPLE                RESIDENCE
#
#   Arrest Domestic              ...               Ward Community Area FBI Code  \
# 0  false    false              ...                 45             12       06
# 1  false    false              ...                  2             27       06
# 2  false    false              ...                 18             71      08A
# 3   true    false              ...                 36             18       07
# 4  false     true              ...                 27             23      08B
#
#   X Coordinate Y Coordinate  Year              Updated On      Latitude  \
# 0      1141968      1935401  2015  07/12/2015 12:42:46 PM  41.978806522
# 1      1157856      1896704  2015  07/12/2015 12:42:46 PM  41.872309009
# 2      1164744      1853262  2015  07/12/2015 12:42:46 PM  41.752956036
# 3      1130361      1916262  2015  07/12/2015 12:42:46 PM  41.926494742
# 4                            2015  07/12/2015 12:42:46 PM
#
#        Longitude                       Location
# 0  -87.753281779  (41.978806522, -87.753281779)
# 1  -87.695910499  (41.872309009, -87.695910499)
# 2  -87.671849368  (41.752956036, -87.671849368)
# 3   -87.79640881   (41.926494742, -87.79640881)
# 4
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Read Excel

# %% [markdown]
# Data Prep can also load Excel files using the `read_excel` method.

# %%
dflow_default_sheet = dprep.read_excel(path='../data/crime.xlsx')
dflow_default_sheet.head(5)
# Out:
#        Column1      Column2                     Column3              Column4  \
# 0           ID  Case Number                        Date                Block
# 1  1.01405e+07     HY329907  2015-07-05T23:50:00.000000  050XX N NEWLAND AVE
# 2  1.01398e+07     HY329265  2015-07-05T23:30:00.000000    011XX W MORSE AVE
# 3  1.01403e+07     HY329253  2015-07-05T23:20:00.000000    121XX S FRONT AVE
# 4  1.01399e+07     HY329308  2015-07-05T23:19:00.000000  051XX W DIVISION ST
#
#   Column5       Column6                  Column7               Column8  \
# 0    IUCR  Primary Type              Description  Location Description
# 1     820         THEFT           $500 AND UNDER                STREET
# 2     460       BATTERY                   SIMPLE                STREET
# 3     486       BATTERY  DOMESTIC BATTERY SIMPLE                STREET
# 4     610      BURGLARY           FORCIBLE ENTRY    SMALL RETAIL STORE
#
#   Column9  Column10              ...               Column13        Column14  \
# 0  Arrest  Domestic              ...                   Ward  Community Area
# 1   False     False              ...                     41              10
# 2   False      True              ...                     49               1
# 3   False      True              ...                      9              53
# 4   False     False              ...                     37              25
#
#    Column15      Column16      Column17 Column18                    Column19  \
# 0  FBI Code  X Coordinate  Y Coordinate     Year                  Updated On
# 1         6   1.12923e+06   1.93332e+06     2015  2015-07-12T12:42:46.000000
# 2       08B   1.16737e+06   1.94627e+06     2015  2015-07-12T12:42:46.000000
# 3       08B          None          None     2015  2015-07-12T12:42:46.000000
# 4         5   1.14172e+06   1.90746e+06     2015  2015-07-12T12:42:46.000000
#
#    Column20   Column21                       Column22
# 0  Latitude  Longitude                       Location
# 1   41.9733   -87.8002  (41.973309466, -87.800174996)
# 2   42.0081   -87.6596   (42.008124017, -87.65955018)
# 3      None       None                           None
# 4   41.9022   -87.7549  (41.902152027, -87.754883404)
#
# [5 rows x 22 columns]

# %% [markdown]
# Here, the first sheet of the Excel document has been loaded. You could achieve the same result by specifying the name of the desired sheet explicitly.

# %%
dflow_second_sheet = dprep.read_excel(path='../data/crime.xlsx', sheet_name='Sheet2')
dflow_second_sheet.head(5)
# Out:
#        Column1      Column2                     Column3              Column4  \
# 0         None         None                        None                 None
# 1         None         None                        None                 None
# 2         None         None                        None                 None
# 3           ID  Case Number                        Date                Block
# 4  1.01405e+07     HY329907  2015-07-05T23:50:00.000000  050XX N NEWLAND AVE
#
#   Column5       Column6         Column7               Column8 Column9  \
# 0    None          None            None                  None    None
# 1    None          None            None                  None    None
# 2    None          None            None                  None    None
# 3    IUCR  Primary Type     Description  Location Description  Arrest
# 4     820         THEFT  $500 AND UNDER                STREET   False
#
#   Column10              ...               Column13        Column14  Column15  \
# 0     None              ...                   None            None      None
# 1     None              ...                   None            None      None
# 2     None              ...                   None            None      None
# 3  Column2              ...                   Ward  Community Area  FBI Code
# 4    False              ...                     41              10         6
#
#        Column16      Column17 Column18                    Column19  Column20  \
# 0          None          None     None                        None      None
# 1          None          None     None                        None      None
# 2          None          None     None                        None      None
# 3  X Coordinate  Y Coordinate     Year                  Updated On  Latitude
# 4   1.12923e+06   1.93332e+06     2015  2015-07-12T12:42:46.000000   41.9733
#
#     Column21                       Column22
# 0       None                           None
# 1       None                           None
# 2       None                           None
# 3  Longitude                       Location
# 4   -87.8002  (41.973309466, -87.800174996)
#
# [5 rows x 22 columns]

# %% [markdown]
# As you can see, the table in the second sheet had headers as well as three empty rows, so you can modify the arguments accordingly.

# %%
dflow_skipped_rows = dprep.read_excel(path='../data/crime.xlsx',
                                      sheet_name='Sheet2',
                                      use_column_headers=True,
                                      skip_rows=3)
dflow_skipped_rows.head(5)
# Out:
#            ID Case Number                Date                Block   IUCR  \
# 0  10140490.0    HY329907 2015-07-05 23:50:00  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265 2015-07-05 23:30:00    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253 2015-07-05 23:20:00    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308 2015-07-05 23:19:00  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556 2015-07-05 23:00:00      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Column2              ...                Ward  Community Area  \
# 0  False   False              ...                41.0            10.0
# 1  False    True              ...                49.0             1.0
# 2  False    True              ...                 9.0            53.0
# 3  False   False              ...                37.0            25.0
# 4  False   False              ...                27.0            28.0
#
#    FBI Code  X Coordinate Y Coordinate    Year          Updated On   Latitude  \
# 0         6     1129230.0    1933315.0  2015.0 2015-07-12 12:42:46  41.973309
# 1       08B     1167370.0    1946271.0  2015.0 2015-07-12 12:42:46  42.008124
# 2       08B           NaN          NaN  2015.0 2015-07-12 12:42:46        NaN
# 3         5     1141721.0    1907465.0  2015.0 2015-07-12 12:42:46  41.902152
# 4         7     1168413.0    1901632.0  2015.0 2015-07-12 12:42:46  41.885610
#
#    Longitude                       Location
# 0 -87.800175  (41.973309466, -87.800174996)
# 1 -87.659550   (42.008124017, -87.65955018)
# 2        NaN                           None
# 3 -87.754883  (41.902152027, -87.754883404)
# 4 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %%
df = dflow_skipped_rows.to_pandas_dataframe()
df
# Out:
#            ID Case Number                Date                     Block  \
# 0  10140490.0    HY329907 2015-07-05 23:50:00       050XX N NEWLAND AVE
# 1  10139776.0    HY329265 2015-07-05 23:30:00         011XX W MORSE AVE
# 2  10140270.0    HY329253 2015-07-05 23:20:00         121XX S FRONT AVE
# 3  10139885.0    HY329308 2015-07-05 23:19:00       051XX W DIVISION ST
# 4  10140379.0    HY329556 2015-07-05 23:00:00           012XX W LAKE ST
# 5  10140868.0    HY330421 2015-07-05 22:54:00         118XX S PEORIA ST
# 6  10139762.0    HY329232 2015-07-05 22:42:00           026XX W 37TH PL
# 7  10139722.0    HY329228 2015-07-05 22:30:00  016XX S CENTRAL PARK AVE
# 8  10139774.0    HY329209 2015-07-05 22:15:00       048XX N ASHLAND AVE
# 9  10139697.0    HY329177 2015-07-05 22:10:00      058XX S ARTESIAN AVE
#
#      IUCR         Primary Type                   Description  \
# 0   820.0                THEFT                $500 AND UNDER
# 1   460.0              BATTERY                        SIMPLE
# 2   486.0              BATTERY       DOMESTIC BATTERY SIMPLE
# 3   610.0             BURGLARY                FORCIBLE ENTRY
# 4   930.0  MOTOR VEHICLE THEFT    THEFT/RECOVERY: AUTOMOBILE
# 5  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
# 6  1020.0                ARSON                       BY FIRE
# 7  1811.0            NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 8  1310.0      CRIMINAL DAMAGE                   TO PROPERTY
# 9  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
#
#      Location Description Arrest Column2              ...                Ward  \
# 0                  STREET  False   False              ...                41.0
# 1                  STREET  False    True              ...                49.0
# 2                  STREET  False    True              ...                 9.0
# 3      SMALL RETAIL STORE  False   False              ...                37.0
# 4                  STREET  False   False              ...                27.0
# 5  VEHICLE NON-COMMERCIAL  False   False              ...                34.0
# 6         VACANT LOT/LAND  False   False              ...                12.0
# 7                   ALLEY   True   False              ...                24.0
# 8               APARTMENT  False   False              ...                46.0
# 9                   ALLEY  False   False              ...                16.0
#
#    Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0            10.0         6     1129230.0    1933315.0  2015.0
# 1             1.0       08B     1167370.0    1946271.0  2015.0
# 2            53.0       08B           NaN          NaN  2015.0
# 3            25.0         5     1141721.0    1907465.0  2015.0
# 4            28.0         7     1168413.0    1901632.0  2015.0
# 5            53.0        14     1172409.0    1826485.0  2015.0
# 6            58.0         9     1159436.0    1879658.0  2015.0
# 7            29.0        18     1152687.0    1891389.0  2015.0
# 8             3.0        14     1164821.0    1932394.0  2015.0
# 9            63.0        14     1160997.0    1865851.0  2015.0
#
#            Updated On   Latitude  Longitude                       Location
# 0 2015-07-12 12:42:46  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1 2015-07-12 12:42:46  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2 2015-07-12 12:42:46        NaN        NaN                           None
# 3 2015-07-12 12:42:46  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4 2015-07-12 12:42:46  41.885610 -87.657009  (41.885610142, -87.657008701)
# 5 2015-07-12 12:42:46  41.679311 -87.644545    (41.6793109, -87.644545209)
# 6 2015-07-12 12:42:46  41.825501 -87.690578  (41.825500607, -87.690578042)
# 7 2015-07-12 12:42:46  41.857828 -87.715029  (41.857827814, -87.715028789)
# 8 2015-07-12 12:42:46  41.970100 -87.669324  (41.970099796, -87.669324377)
# 9 2015-07-12 12:42:46  41.787580 -87.685233  (41.787580282, -87.685233078)
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Read Fixed Width Files

# %% [markdown]
# For fixed-width files, you can specify a list of offsets. The first column is always assumed to start at offset 0.

# %%
dflow_fixed_width = dprep.read_fwf('../data/crime.txt', offsets=[8, 17, 26, 33, 56, 58, 74])
dflow_fixed_width.head(5)
# Out:
#    10140490   HY329907   7/5/2015    23:50                    050XX   N  \
# 0  10139776   HY329265   7/5/2015    23:30                    011XX   W
# 1  10140270   HY329253   7/5/2015    23:20                    121XX   S
# 2  10139885   HY329308   7/5/2015    23:19                    051XX   W
# 3  10140379   HY329556   7/5/2015    23:00                    012XX   W
# 4  10140868   HY330421   7/5/2015    22:54                    118XX   S
#
#     NEWLAND AVE 820                THEFT
# 0   MORSE AVE 460                BATTERY
# 1   FRONT AVE 486                BATTERY
# 2   DIVISION ST 610             BURGLARY
# 3   LAKE ST 930      MOTOR VEHICLE THEFT
# 4   PEORIA ST 1320       CRIMINAL DAMAGE

# %% [markdown]
# Looking at the data, you can see that the first row was used as headers. In this particular case, however, there are no headers in the file, so the first row should be treated as data.
#
# Passing in `PromoteHeadersMode.NONE` to the `header` keyword argument avoids header detection and gets the correct data.

# %%
dflow_no_headers = dprep.read_fwf('../data/crime.txt',
                          offsets=[8, 17, 26, 33, 56, 58, 74],
                          header=dprep.PromoteHeadersMode.NONE)
dflow_no_headers.head(5)
# Out:
#     Column1    Column2    Column3  Column4                  Column5 Column6  \
# 0  10140490   HY329907   7/5/2015    23:50                    050XX       N
# 1  10139776   HY329265   7/5/2015    23:30                    011XX       W
# 2  10140270   HY329253   7/5/2015    23:20                    121XX       S
# 3  10139885   HY329308   7/5/2015    23:19                    051XX       W
# 4  10140379   HY329556   7/5/2015    23:00                    012XX       W
#
#             Column7                     Column8
# 0   NEWLAND AVE 820      THEFT
# 1   MORSE AVE 460                       BATTERY
# 2   FRONT AVE 486                       BATTERY
# 3   DIVISION ST 610                    BURGLARY
# 4   LAKE ST 930             MOTOR VEHICLE THEFT

# %%
df = dflow_no_headers.to_pandas_dataframe()
df
# Out:
#     Column1    Column2    Column3  Column4                  Column5 Column6  \
# 0  10140490   HY329907   7/5/2015    23:50                    050XX       N
# 1  10139776   HY329265   7/5/2015    23:30                    011XX       W
# 2  10140270   HY329253   7/5/2015    23:20                    121XX       S
# 3  10139885   HY329308   7/5/2015    23:19                    051XX       W
# 4  10140379   HY329556   7/5/2015    23:00                    012XX       W
# 5  10140868   HY330421   7/5/2015    22:54                    118XX       S
# 6  10139762   HY329232   7/5/2015    22:42                    026XX       W
# 7  10139722   HY329228   7/5/2015    22:30                    016XX       S
# 8  10139774   HY329209   7/5/2015    22:15                    048XX       N
# 9  10139697   HY329177   7/5/2015    22:10                    058XX       S
#
#             Column7                     Column8
# 0   NEWLAND AVE 820      THEFT
# 1   MORSE AVE 460                       BATTERY
# 2   FRONT AVE 486                       BATTERY
# 3   DIVISION ST 610                    BURGLARY
# 4   LAKE ST 930             MOTOR VEHICLE THEFT
# 5   PEORIA ST 1320              CRIMINAL DAMAGE
# 6   37TH PL 1020                          ARSON
# 7   CENTRAL PARK AV         E 1811    NARCOTICS
# 8   ASHLAND AVE 131        0    CRIMINAL DAMAGE
# 9   ARTESIAN AVE 13       20    CRIMINAL DAMAGE

# %% [markdown]
# ## Read Parquet

# %% [markdown]
# Data Prep has two different methods for reading data stored as Parquet.
#
# Currently they both require `pyarrow>=0.11.0` to be installed in your Python enviornment.

# %% [markdown]
# ### Read Parquet File

# %% [markdown]
# For reading single `.parquet` files, or a folder full of only Parquet files, use `read_parquet_file`.

# %%
dflow = dprep.read_parquet_file('../data/crime.parquet')
dflow.head(5)
# Out:
#            ID Case Number                Date                Block   IUCR  \
# 0  10140490.0    HY329907 2015-07-05 23:50:00  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265 2015-07-05 23:30:00    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253 2015-07-05 23:20:00    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308 2015-07-05 23:19:00  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556 2015-07-05 23:00:00      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic              ...                Ward  Community Area  \
# 0  False    False              ...                41.0            10.0
# 1  False     True              ...                49.0             1.0
# 2  False     True              ...                 9.0            53.0
# 3  False    False              ...                37.0            25.0
# 4  False    False              ...                27.0            28.0
#
#    FBI Code  X Coordinate Y Coordinate    Year          Updated On   Latitude  \
# 0        06     1129230.0    1933315.0  2015.0 2015-07-12 12:42:46  41.973309
# 1       08B     1167370.0    1946271.0  2015.0 2015-07-12 12:42:46  42.008124
# 2       08B           NaN          NaN  2015.0 2015-07-12 12:42:46        NaN
# 3        05     1141721.0    1907465.0  2015.0 2015-07-12 12:42:46  41.902152
# 4        07     1168413.0    1901632.0  2015.0 2015-07-12 12:42:46  41.885610
#
#    Longitude                       Location
# 0 -87.800175  (41.973309466, -87.800174996)
# 1 -87.659550   (42.008124017, -87.65955018)
# 2        NaN
# 3 -87.754883  (41.902152027, -87.754883404)
# 4 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %% [markdown]
# Parquet data is explicitly typed so no type inference is needed.

# %%
dflow.dtypes
# Out:
# ID                       FieldType.DECIMAL
# Block                    FieldType.STRING
# Community Area           FieldType.DECIMAL
# IUCR                     FieldType.DECIMAL
# Year                     FieldType.DECIMAL
# Date                     FieldType.DATE
# Arrest                   FieldType.BOOLEAN
# Updated On               FieldType.DATE
# Latitude                 FieldType.DECIMAL
# Case Number              FieldType.STRING
# Beat                     FieldType.DECIMAL
# Ward                     FieldType.DECIMAL
# Longitude                FieldType.DECIMAL
# Location Description     FieldType.STRING
# Y Coordinate             FieldType.DECIMAL
# Description              FieldType.STRING
# FBI Code                 FieldType.STRING
# Primary Type             FieldType.STRING
# District                 FieldType.DECIMAL
# Domestic                 FieldType.BOOLEAN
# X Coordinate             FieldType.DECIMAL
# Location                 FieldType.STRING

# %% [markdown]
# ### Read Parquet Dataset

# %% [markdown]
# A Parquet Dataset is different from a Parquet file in that it could be a folder containing a number of Parquet files within a complex directory structure. It may have a hierarchical structure that partitions the data by value of a column. These more complex forms of Parquet data are commonly produced by Spark/HIVE.
#
# For these more complex data sets, you can use `read_parquet_dataset`, which uses pyarrow to handle complex Parquet layouts. This will also handle single Parquet files, though these are better read using `read_parquet_file`.

# %%
dflow = dprep.read_parquet_dataset('../data/parquet_dataset')
dflow.head(5)
# Out:
#            ID Case_Number                Date                Block  IUCR  \
# 0  10140490.0    HY329907 2015-07-06 06:50:00  050XX N NEWLAND AVE  0820
# 1  10139776.0    HY329265 2015-07-06 06:30:00    011XX W MORSE AVE  0460
# 2  10140270.0    HY329253 2015-07-06 06:20:00    121XX S FRONT AVE  0486
# 3  10139885.0    HY329308 2015-07-06 06:19:00  051XX W DIVISION ST  0610
# 4  10140379.0    HY329556 2015-07-06 06:00:00      012XX W LAKE ST  0930
#
#           Primary_Type                 Description Location_Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Domestic    Beat   ...    Community_Area  FBI_Code  X_Coordinate  \
# 0    False  1613.0   ...              10.0        06     1129230.0
# 1     True  2431.0   ...               1.0       08B     1167370.0
# 2     True   532.0   ...              53.0       08B           NaN
# 3    False  1531.0   ...              25.0        05     1141721.0
# 4    False  1215.0   ...              28.0        07     1168413.0
#
#   Y_Coordinate    Year          Updated_On   Latitude  Longitude  \
# 0    1933315.0  2015.0 2015-07-12 19:42:46  41.973309 -87.800175
# 1    1946271.0  2015.0 2015-07-12 19:42:46  42.008124 -87.659550
# 2          NaN  2015.0 2015-07-12 19:42:46        NaN        NaN
# 3    1907465.0  2015.0 2015-07-12 19:42:46  41.902152 -87.754883
# 4    1901632.0  2015.0 2015-07-12 19:42:46  41.885610 -87.657009
#
#                         Location  Arrest
# 0  (41.973309466, -87.800174996)   false
# 1   (42.008124017, -87.65955018)   false
# 2                                  false
# 3  (41.902152027, -87.754883404)   false
# 4  (41.885610142, -87.657008701)   false
#
# [5 rows x 22 columns]

# %% [markdown]
# The above data was partitioned by the value of the `Arrest` column. It is a boolean column in the original crime0 data set and hence was partitioned by `Arrest=true` and `Arrest=false`.
#
# The directory structure is printed below for clarity.

# %%
import os
for path, dirs, files in os.walk('../data/parquet_dataset'):
    level = path.replace('../data/parquet_dataset', '').count(os.sep)
    indent = '   ' * (level)
    print(indent + os.path.basename(path) + '/')
    fileindent = '   ' * (level + 1)
    for f in files:
        print(fileindent + f)
# Out:
# parquet_dataset/
#    Arrest=true/
#       part-00000-34f8a7a7-c3cd-4926-92b2-ba2dcd3f95b7.gz.parquet
#    Arrest=false/
#       part-00000-34f8a7a7-c3cd-4926-92b2-ba2dcd3f95b7.gz.parquet

# %% [markdown]
# ## Read JSON

# %% [markdown]
# Data Prep can also load JSON files.

# %%
dflow_json = dprep.read_json(path='../data/json.json')
dflow_json.head(15)
# Out:
#    inspections.business.business_id        inspections.business.name  \
# 0                             16162        Quick-N-Ezee Indian Foods
# 1                             69707             Little Green Cyclo 2
# 2                             67565        King of Thai Noodles Cafe
# 3                             67565        King of Thai Noodles Cafe
# 4                             68701                           Grindz
# 5                             69186  Premier Catering & Events, Inc.
# 6                              2689                   THE BLUE PLATE
# 7                             15806                   Vital Tea Leaf
# 8                             21807                  The Front Porch
# 9                             69041                  Washington Cafe
# 10                             6018      3RD BAPTIST FELLOWSHIP HALL
# 11                            23702                Doo Bu Restaurant
# 12                            23702                Doo Bu Restaurant
# 13                            34244               Vital Tea Leaf Inc
# 14                            63503     Mason Street Deli and Market
#
#    inspections.business.address inspections.business.city  \
# 0                 3861 24th St                         SF
# 1                Off The Grid
# 2              1541 TARAVAL St              SAN FRANCISCO
# 3              1541 TARAVAL St              SAN FRANCISCO
# 4               832 Clement St                         SF
# 5                 1255 22nd St                       S.F.
# 6              3218 MISSION St                         SF
# 7                1044 Grant Ave             San Francisco
# 8                  65 29th St A                        SF
# 9            826 Washington St              San Francisco
# 10          1399 MCALLISTER St              SAN FRANCISCO
# 11             1723 Buchanan St             San Francisco
# 12             1723 Buchanan St             San Francisco
# 13               905 Grant Ave              San Francisco
# 14                     39 MASON                        SF
#
#    inspections.business.postal_code inspections.business.latitude  \
# 0                             94114
# 1
# 2                             94116                       37.7427
# 3                             94116                       37.7427
# 4                             94118                       37.7828
# 5                             94107
# 6                             94110                       37.7452
# 7                             94133                       37.7966
# 8                             94110                       37.7439
# 9                             94108                       37.7951
# 10                            94115                       37.7782
# 11                            94115                        37.786
# 12                            94115                        37.786
# 13                            94108                       37.7953
# 14                            94102                       37.7841
#
#    inspections.business.longitude inspections.business.phone_number  \
# 0
# 1
# 2                        -122.483
# 3                        -122.483
# 4                        -122.468
# 5                                                       14155530288
# 6                         -122.42                       14155286777
# 7                        -122.407
# 8                        -122.422
# 9                        -122.407
# 10                       -122.435
# 11                        -122.43
# 12                        -122.43
# 13                       -122.407
# 14                       -122.409                       14155624312
#
#    inspections.business.TaxCode inspections.business.business_certificate  \
# 0                           H34                                    467114
# 1                           H79                                    453248
# 2                           H25
# 3                           H25
# 4                           H25                                    467498
# 5                           H30                                    362812
# 6                           H25                                    325714
# 7                           H24                                    388301
# 8                           H25                                    398500
# 9                           H26                                    468548
# 10                           AA
# 11                          H25                                    205289
# 12                          H25                                    205289
# 13                          H25                                    417300
# 14                          H07                                    450988
#
#    inspections.business.application_date  \
# 0                    May  9 2005 12:00AM
# 1                    Jul 12 2012 12:00AM
# 2                    Oct 12 2011 12:00AM
# 3                    Oct 12 2011 12:00AM
# 4                    Mar 16 2012 12:00AM
# 5                    Apr 30 2012 12:00AM
# 6
# 7                    May 23 2005 12:00AM
# 8                    Jun  7 2006 12:00AM
# 9                    Apr 18 2012 12:00AM
# 10
# 11                   Jun 30 2006 12:00AM
# 12                   Jun 30 2006 12:00AM
# 13                   May 17 2007 12:00AM
# 14                   Jun 28 2010 12:00AM
#
#                       inspections.business.owner_name  \
# 0                                Jagpreet Enterprises
# 1                                LITTLEGREENCYCLO LLC
# 2                             Royal Thai Noodles, Inc
# 3                             Royal Thai Noodles, Inc
# 4                                     Ono Grindz, LLC
# 5                     Premier Catering & Events, Inc.
# 6                                    BLUE ENCLAVE LLC
# 7                                       Minh H. Duong
# 8                          Front Porch Restaurant LLC
# 9                 Washington Caf�, Inc. / Louis Kuang
# 10                        3RD BAPTIST FELLOWSHIP HALL
# 11                                       Jung Un Hong
# 12                                       Jung Un Hong
# 13               Vital Tea Leaf Inc   Minh Hong Duong
# 14  Hifdallah Ahmed Homran and Arkan Ali Hassan Al...
#
#                    inspections.business.owner_address inspections.Score  \
# 0          23682 Clawiter Road\n Hayward\n CA\n 94545               100
# 1   100 Esplanade Ave., Apt. 99\n Pacifica\n CA\n ...                93
# 2                     2410 19th Ave\n SF\n CA\n 94116                79
# 3                     2410 19th Ave\n SF\n CA\n 94116
# 4             1055 Granada St.\n Vallejo\n CA\n 94591               100
# 5                 298 Magellan Ave.\n SF\n CA\n 94116
# 6       3218 MISSION ST.\n SAN FRANCISCO\n CA\n 94110                98
# 7         1044 Grant Ave\n San Francisco\n CA\n 94133                98
# 8                   65A 29th Street\n SF\n CA\n 94110
# 9           333 Third Avenue\n Daly City\n CA\n 94014                65
# 10  1399 MC ALLISTER STREET\n SAN FRANCISCO\n CA\n...                98
# 11      1723 Buchanan St\n San Francisco\n CA\n 94115                90
# 12      1723 Buchanan St\n San Francisco\n CA\n 94115
# 13         905 Grant Ave\n San Francisco\n CA\n 94108               100
# 14       39 Mason Street\n San Francisco\n CA\n 94102               100
#
#    inspections.date       inspections.type  \
# 0          20130223  Routine - Unscheduled
# 1          20130224  Routine - Unscheduled
# 2          20130225  Routine - Unscheduled
# 3          20130225              Complaint
# 4          20130225  Routine - Unscheduled
# 5          20130225  Reinspection/Followup
# 6          20130225  Routine - Unscheduled
# 7          20130225  Routine - Unscheduled
# 8          20130225  Reinspection/Followup
# 9          20130225  Routine - Unscheduled
# 10         20130225  Routine - Unscheduled
# 11         20130225  Routine - Unscheduled
# 12         20130225              Complaint
# 13         20130225  Routine - Unscheduled
# 14         20130225  Routine - Unscheduled
#
#                                inspections.violations
# 0                                                  []
# 1   [{"description":"103112: No hot water or runni...
# 2   [{"description":"103139: Improper food storage...
# 3   [{"description":"103139: Improper food storage...
# 4                                                  []
# 5                                                  []
# 6   [{"description":"103143: Inadequate warewashin...
# 7   [{"description":"103157: Food safety certifica...
# 8                                                  []
# 9   [{"description":"103120: Moderate risk food ho...
# 10  [{"description":"103143: Inadequate warewashin...
# 11  [{"description":"103154: Unclean or degraded f...
# 12  [{"description":"103154: Unclean or degraded f...
# 13                                                 []
# 14                                                 []

# %% [markdown]
# When you use `read_json`, Data Prep will attempt to extract data from the file into a table. You can also control the file encoding Data Prep should use as well as whether Data Prep should flatten nested JSON arrays.
#
# Choosing the option to flatten nested arrays could result in a much larger number of rows.

# %%
dflow_flat_arrays = dprep.read_json(path='../data/json.json', flatten_nested_arrays=True)
dflow_flat_arrays.head(5)
# Out:
#   inspections.business.business_id  inspections.business.name  \
# 0                            16162  Quick-N-Ezee Indian Foods
# 1                            69707       Little Green Cyclo 2
# 2                            67565  King of Thai Noodles Cafe
# 3                            67565  King of Thai Noodles Cafe
# 4                            67565  King of Thai Noodles Cafe
#
#   inspections.business.address inspections.business.city  \
# 0                3861 24th St                         SF
# 1               Off The Grid
# 2             1541 TARAVAL St              SAN FRANCISCO
# 3             1541 TARAVAL St              SAN FRANCISCO
# 4             1541 TARAVAL St              SAN FRANCISCO
#
#   inspections.business.postal_code inspections.business.latitude  \
# 0                            94114
# 1
# 2                            94116                       37.7427
# 3                            94116                       37.7427
# 4                            94116                       37.7427
#
#   inspections.business.longitude inspections.business.phone_number  \
# 0
# 1
# 2                       -122.483
# 3                       -122.483
# 4                       -122.483
#
#   inspections.business.TaxCode inspections.business.business_certificate  \
# 0                          H34                                    467114
# 1                          H79                                    453248
# 2                          H25
# 3                          H25
# 4                          H25
#
#   inspections.business.application_date inspections.business.owner_name  \
# 0                   May  9 2005 12:00AM            Jagpreet Enterprises
# 1                   Jul 12 2012 12:00AM            LITTLEGREENCYCLO LLC
# 2                   Oct 12 2011 12:00AM         Royal Thai Noodles, Inc
# 3                   Oct 12 2011 12:00AM         Royal Thai Noodles, Inc
# 4                   Oct 12 2011 12:00AM         Royal Thai Noodles, Inc
#
#                   inspections.business.owner_address inspections.Score  \
# 0         23682 Clawiter Road\n Hayward\n CA\n 94545               100
# 1  100 Esplanade Ave., Apt. 99\n Pacifica\n CA\n ...                93
# 2                    2410 19th Ave\n SF\n CA\n 94116                79
# 3                    2410 19th Ave\n SF\n CA\n 94116                79
# 4                    2410 19th Ave\n SF\n CA\n 94116                79
#
#   inspections.date       inspections.type  \
# 0         20130223  Routine - Unscheduled
# 1         20130224  Routine - Unscheduled
# 2         20130225  Routine - Unscheduled
# 3         20130225  Routine - Unscheduled
# 4         20130225  Routine - Unscheduled
#
#                   inspections.violations.description
# 0                                               None
# 1  103112: No hot water or running water (High Risk)
# 2           103139: Improper food storage (Low Risk)
# 3  103119: Inadequate and inaccessible handwashin...
# 4  103120: Moderate risk food holding temperature...

# %% [markdown]
# ## Read SQL

# %% [markdown]
# Data Prep can also fetch data from SQL servers. Currently, only Microsoft SQL Server is supported.
#
# To read data from a SQL server, first create a data source object that contains the connection information.

# %%
secret = dprep.register_secret(value="dpr3pTestU$er", id="dprepTestUser")
ds = dprep.MSSQLDataSource(server_name="dprep-sql-test.database.windows.net",
                           database_name="dprep-sql-test",
                           user_name="dprepTestUser",
                           password=secret)

# %% [markdown]
# As you can see, the password parameter of `MSSQLDataSource` accepts a Secret object. You can get a Secret object in two ways:
# 1. Register the secret and its value with the execution engine.
# 2. Create the secret with just an id (useful if the secret value was already registered in the execution environment).
#
# Now that you have created a data source object, you can proceed to read data.

# %%
dflow = dprep.read_sql(ds, "SELECT top 100 * FROM [SalesLT].[Product]")
dflow.head(5)
# Out:
#    ProductID                       Name ProductNumber  Color  StandardCost  \
# 0        680  HL Road Frame - Black, 58    FR-R92B-58  Black     1059.3100
# 1        706    HL Road Frame - Red, 58    FR-R92R-58    Red     1059.3100
# 2        707      Sport-100 Helmet, Red     HL-U509-R    Red       13.0863
# 3        708    Sport-100 Helmet, Black       HL-U509  Black       13.0863
# 4        709     Mountain Bike Socks, M     SO-B909-M  White        3.3963
#
#    ListPrice  Size   Weight  ProductCategoryID  ProductModelID SellStartDate  \
# 0    1431.50    58  1016.04                 18               6    2002-06-01
# 1    1431.50    58  1016.04                 18               6    2002-06-01
# 2      34.99  None      NaN                 35              33    2005-07-01
# 3      34.99  None      NaN                 35              33    2005-07-01
# 4       9.50     M      NaN                 27              18    2005-07-01
#
#                   SellEndDate DiscontinuedDate  \
# 0                        None             None
# 1                        None             None
# 2                        None             None
# 3                        None             None
# 4  2006-06-30T00:00:00.000000             None
#
#                                       ThumbNailPhoto  \
# 0  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 1  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 2  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 3  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 4  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
#
#          ThumbnailPhotoFileName                               rowguid  \
# 0  no_image_available_small.gif  43dd68d6-14a4-461f-9069-55309d90ea7e
# 1  no_image_available_small.gif  9540ff17-2712-4c90-a3d1-8ce5568b2462
# 2  no_image_available_small.gif  2e1ef41a-c08a-4ff6-8ada-bde58b64a712
# 3  no_image_available_small.gif  a25a44fb-c2de-4268-958f-110b8d7621e2
# 4  no_image_available_small.gif  18f95f47-1540-4e02-8f1f-cc1bcb6828d0
#
#              ModifiedDate
# 0 2008-03-11 10:01:36.827
# 1 2008-03-11 10:01:36.827
# 2 2008-03-11 10:01:36.827
# 3 2008-03-11 10:01:36.827
# 4 2008-03-11 10:01:36.827

# %%
df = dflow.to_pandas_dataframe()
df.dtypes
# Out:
# ProductID                          int64
# Name                              object
# ProductNumber                     object
# Color                             object
# StandardCost                     float64
# ListPrice                        float64
# Size                              object
# Weight                           float64
# ProductCategoryID                  int64
# ProductModelID                     int64
# SellStartDate             datetime64[ns]
# SellEndDate                       object
# DiscontinuedDate                  object
# ThumbNailPhoto                    object
# ThumbnailPhotoFileName            object
# rowguid                           object
# ModifiedDate              datetime64[ns]
# dtype: object

# %% [markdown]
# ## Read from ADLS

# %% [markdown]
# There are two ways the Data Prep API can acquire the necessary OAuth token to access Azure DataLake Storage:
# 1. Retrieve the access token from a recent login session of the user's [Azure CLI](https://docs.microsoft.com/en-us/cli/azure/install-azure-cli?view=azure-cli-latest) login.
# 2. Use a ServicePrincipal (SP) and a certificate as a secret.

# %% [markdown]
# ### Using Access Token from a recent Azure CLI session

# %% [markdown]
# On your local machine, run the following command:
# ```
# az login
# ```
# If your user account is a member of more than one Azure tenant, you need to specify the tenant, either in the AAD url hostname form '<your_domain>.onmicrosoft.com' or the tenantId GUID. The latter can be retrieved as follows:
# ```
# az account show --query tenantId
# ```

# %% [markdown]
# ```python
# dflow = read_csv(path = DataLakeDataSource(path='adl://dpreptestfiles.azuredatalakestore.net/farmers-markets.csv', tenant='microsoft.onmicrosoft.com'))
# head = dflow.head(5)
# head
# ```

# %% [markdown]
# ### Create a ServicePrincipal via Azure CLI

# %% [markdown]
# A ServicePrincipal and the corresponding certificate can be created via [Azure CLI](https://docs.microsoft.com/en-us/cli/azure/install-azure-cli?view=azure-cli-latest).
# This particular SP is configured as Reader, with its scope reduced to just the ADLS account 'dpreptestfiles'.
# ```
# az account set --subscription "Data Wrangling development"
# az ad sp create-for-rbac -n "SP-ADLS-dpreptestfiles" --create-cert --role reader --scopes /subscriptions/35f16a99-532a-4a47-9e93-00305f6c40f2/resourceGroups/dpreptestfiles/providers/Microsoft.DataLakeStore/accounts/dpreptestfiles
# ```
# This command emits the appId and the path to the certificate file (usually in the home folder). The .crt file contains both the public certificate and the private key in PEM format.
#
# Extract the thumbprint with:
# ```
# openssl x509 -in adls-dpreptestfiles.crt -noout -fingerprint
# ```

# %% [markdown]
# ### Configure ADLS Account for ServicePrincipal

# %% [markdown]
# To configure the ACL for the ADLS filesystem, use the objectId of the user or, here, ServicePrincipal:
# ```
# az ad sp show --id "8dd38f34-1fcb-4ff9-accd-7cd60b757174" --query objectId
# ```
# Configure Read and Execute access for the ADLS file system. Since the underlying HDFS ACL model doesn't support inheritance, folders and files need to be ACL-ed individually.
# ```
# az dls fs access set-entry --account dpreptestfiles --acl-spec "user:e37b9b1f-6a5e-4bee-9def-402b956f4e6f:r-x" --path /
# az dls fs access set-entry --account dpreptestfiles --acl-spec "user:e37b9b1f-6a5e-4bee-9def-402b956f4e6f:r--" --path /farmers-markets.csv
# ```
#
# References:
# - [az ad sp](https://docs.microsoft.com/en-us/cli/azure/ad/sp?view=azure-cli-latest)
# - [az dls fs access](https://docs.microsoft.com/en-us/cli/azure/dls/fs/access?view=azure-cli-latest)
# - [ACL model for ADLS](https://github.com/MicrosoftDocs/azure-docs/blob/master/articles/data-lake-store/data-lake-store-access-control.md)

# %%
certThumbprint = 'C2:08:9D:9E:D1:74:FC:EB:E9:7E:63:96:37:1C:13:88:5E:B9:2C:84'
certificate = ''
with open('../data/adls-dpreptestfiles.crt', 'rt', encoding='utf-8') as crtFile:
    certificate = crtFile.read()

servicePrincipalAppId = "8dd38f34-1fcb-4ff9-accd-7cd60b757174"

# %% [markdown]
# ### Acquire an OAuth Access Token

# %% [markdown]
# Use the adal package (via: `pip install adal`) to create an authentication context on the MSFT tenant and acquire an OAuth access token. Note that for ADLS, the `resource` in the token request must be for 'https://datalake.azure.net', which is different from most other Azure resources.

# %%
import adal
from azureml.dataprep.api.datasources import DataLakeDataSource

ctx = adal.AuthenticationContext('https://login.microsoftonline.com/microsoft.onmicrosoft.com')
token = ctx.acquire_token_with_client_certificate('https://datalake.azure.net/', servicePrincipalAppId, certificate, certThumbprint)
dflow = dprep.read_csv(path = DataLakeDataSource(path='adl://dpreptestfiles.azuredatalakestore.net/crime-spring.csv', accessToken=token['accessToken']))
dflow.to_pandas_dataframe().head()
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Read Pandas DataFrame

# %% [markdown]
# There are situations where you may already have some data in the form of a pandas DataFrame.
# The steps taken to get to this DataFrame may be non-trivial or not easy to convert to Data Prep Steps. The `read_pandas_dataframe` reader can take a DataFrame and use it as the data source for a Dataflow.
#
# You can pass in a path to a directory (that doesn't exist yet) for Data Prep to store the contents of the DataFrame; otherwise, a temporary directory will be made in the system's temp folder. The files written to this directory will be named `part-00000` and so on; they are written out in Data Prep's internal row-based file format.

# %%
dflow = dprep.read_excel(path='../data/crime.xlsx')
dflow = dflow.drop_columns(columns=['Column1'])
df = dflow.to_pandas_dataframe()
df.head(5)
# Out:
#        Column2                     Column3              Column4 Column5  \
# 0  Case Number                        Date                Block    IUCR
# 1     HY329907  2015-07-05T23:50:00.000000  050XX N NEWLAND AVE     820
# 2     HY329265  2015-07-05T23:30:00.000000    011XX W MORSE AVE     460
# 3     HY329253  2015-07-05T23:20:00.000000    121XX S FRONT AVE     486
# 4     HY329308  2015-07-05T23:19:00.000000  051XX W DIVISION ST     610
#
#         Column6                  Column7               Column8 Column9  \
# 0  Primary Type              Description  Location Description  Arrest
# 1         THEFT           $500 AND UNDER                STREET   False
# 2       BATTERY                   SIMPLE                STREET   False
# 3       BATTERY  DOMESTIC BATTERY SIMPLE                STREET   False
# 4      BURGLARY           FORCIBLE ENTRY    SMALL RETAIL STORE   False
#
#    Column10 Column11              ...               Column13        Column14  \
# 0  Domestic     Beat              ...                   Ward  Community Area
# 1     False     1613              ...                     41              10
# 2      True     2431              ...                     49               1
# 3      True      532              ...                      9              53
# 4     False     1531              ...                     37              25
#
#    Column15      Column16      Column17 Column18                    Column19  \
# 0  FBI Code  X Coordinate  Y Coordinate     Year                  Updated On
# 1         6   1.12923e+06   1.93332e+06     2015  2015-07-12T12:42:46.000000
# 2       08B   1.16737e+06   1.94627e+06     2015  2015-07-12T12:42:46.000000
# 3       08B          None          None     2015  2015-07-12T12:42:46.000000
# 4         5   1.14172e+06   1.90746e+06     2015  2015-07-12T12:42:46.000000
#
#    Column20   Column21                       Column22
# 0  Latitude  Longitude                       Location
# 1   41.9733   -87.8002  (41.973309466, -87.800174996)
# 2   42.0081   -87.6596   (42.008124017, -87.65955018)
# 3      None       None                           None
# 4   41.9022   -87.7549  (41.902152027, -87.754883404)
#
# [5 rows x 21 columns]

# %% [markdown]
# After loading in the data you can now do `read_pandas_dataframe`.

# %%
import shutil
cache_dir = 'dflow_df'
shutil.rmtree(cache_dir, ignore_errors=True)
dflow_df = dprep.read_pandas_dataframe(df, cache_dir)

# %%
dflow_df.head(5)
# Out:
#        Column2                     Column3              Column4 Column5  \
# 0  Case Number                        Date                Block    IUCR
# 1     HY329907  2015-07-05T23:50:00.000000  050XX N NEWLAND AVE     820
# 2     HY329265  2015-07-05T23:30:00.000000    011XX W MORSE AVE     460
# 3     HY329253  2015-07-05T23:20:00.000000    121XX S FRONT AVE     486
# 4     HY329308  2015-07-05T23:19:00.000000  051XX W DIVISION ST     610
#
#         Column6                  Column7               Column8 Column9  \
# 0  Primary Type              Description  Location Description  Arrest
# 1         THEFT           $500 AND UNDER                STREET   False
# 2       BATTERY                   SIMPLE                STREET   False
# 3       BATTERY  DOMESTIC BATTERY SIMPLE                STREET   False
# 4      BURGLARY           FORCIBLE ENTRY    SMALL RETAIL STORE   False
#
#    Column10 Column11              ...               Column13        Column14  \
# 0  Domestic     Beat              ...                   Ward  Community Area
# 1     False     1613              ...                     41              10
# 2      True     2431              ...                     49               1
# 3      True      532              ...                      9              53
# 4     False     1531              ...                     37              25
#
#    Column15      Column16      Column17 Column18                    Column19  \
# 0  FBI Code  X Coordinate  Y Coordinate     Year                  Updated On
# 1         6   1.12923e+06   1.93332e+06     2015  2015-07-12T12:42:46.000000
# 2       08B   1.16737e+06   1.94627e+06     2015  2015-07-12T12:42:46.000000
# 3       08B          None          None     2015  2015-07-12T12:42:46.000000
# 4         5   1.14172e+06   1.90746e+06     2015  2015-07-12T12:42:46.000000
#
#    Column20   Column21                       Column22
# 0  Latitude  Longitude                       Location
# 1   41.9733   -87.8002  (41.973309466, -87.800174996)
# 2   42.0081   -87.6596   (42.008124017, -87.65955018)
# 3      None       None                           None
# 4   41.9022   -87.7549  (41.902152027, -87.754883404)
#
# [5 rows x 21 columns]
