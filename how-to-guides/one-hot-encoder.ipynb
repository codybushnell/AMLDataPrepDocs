# %% [markdown]
# # One Hot Encoder
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# Azure ML Data Prep has the ability to perform one hot encoding on a selected column using `one_hot_encode`. The result Dataflow will have a new binary column for each categorical label encountered in the selected column.

# %%
import azureml.dataprep as dprep
dflow = dprep.read_csv(path='../data/crime-spring.csv')
dflow.head(5)
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# To use `one_hot_encode` from a Dataflow, simply specify the source column. `one_hot_encode` will figure out all the distinct values or categorical labels in the source column using the current data, and it will return a new Dataflow with a new binary column for each categorical label. Note that the categorical labels are remembered in the Dataflow step.

# %%
dflow_result = dflow.one_hot_encode(source_column='Location Description')
dflow_result.head(5)
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
#
#        Location Description  Location Description_RESIDENCE  \
# 0                     OTHER                               0
# 1                 RESIDENCE                               1
# 2                 RESIDENCE                               1
# 3                 RESIDENCE                               1
# 4  SCHOOL, PUBLIC, BUILDING                               0
#
#    Location Description_RESTAURANT              ...                Ward  \
# 0                                0              ...                   9
# 1                                0              ...                  21
# 2                                0              ...                  19
# 3                                0              ...                   9
# 4                                0              ...                  40
#
#    Community Area FBI Code X Coordinate Y Coordinate  Year       Updated On  \
# 0              50       11      1183356      1831503  2016  5/11/2016 15:48
# 1              71        6      1166776      1850053  2016  5/12/2016 15:48
# 2              74       11                            2016  5/12/2016 15:50
# 3              49       10                            2016  5/13/2016 15:51
# 4              13        6                            2016  5/25/2016 15:59
#
#       Latitude     Longitude                       Location
# 0  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2
# 3
# 4
#
# [5 rows x 26 columns]

# %% [markdown]
# By default, all the new columns will use the `source_column` name as a prefix. However, if you would like to specify your own prefix, simply pass a `prefix` string as a second parameter.

# %%
dflow_result = dflow.one_hot_encode(source_column='Location Description', prefix='LOCATION_')
dflow_result.head(5)
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
#
#        Location Description  LOCATION_RESIDENCE  LOCATION_RESTAURANT  \
# 0                     OTHER                   0                    0
# 1                 RESIDENCE                   1                    0
# 2                 RESIDENCE                   1                    0
# 3                 RESIDENCE                   1                    0
# 4  SCHOOL, PUBLIC, BUILDING                   0                    0
#
#                ...                Ward  Community Area FBI Code X Coordinate  \
# 0              ...                   9              50       11      1183356
# 1              ...                  21              71        6      1166776
# 2              ...                  19              74       11
# 3              ...                   9              49       10
# 4              ...                  40              13        6
#
#   Y Coordinate  Year       Updated On     Latitude     Longitude  \
# 0      1831503  2016  5/11/2016 15:48  41.69283384  -87.60431945
# 1      1850053  2016  5/12/2016 15:48  41.74410697  -87.66449429
# 2               2016  5/12/2016 15:50
# 3               2016  5/13/2016 15:51
# 4               2016  5/25/2016 15:59
#
#                         Location
# 0   (41.692833841, -87.60431945)
# 1  (41.744106973, -87.664494285)
# 2
# 3
# 4
#
# [5 rows x 26 columns]

# %% [markdown]
# To have more control over the categorical labels, create a builder using `dataflow.builders.one_hot_encode`. The builder allows to preview and modify the categorical labels before generating a new Dataflow with the results.

# %%
builder = dflow_result.builders.one_hot_encode(source_column='Location Description', prefix='LOCATION_')

# %% [markdown]
# To generate the categorical labels, call the `learn` method on the builder object:

# %%
builder.learn()

# %% [markdown]
# To preview the categorical labels, simply access them through the property `categorical_labels` on the builder object:

# %%
builder.categorical_labels
# Out:
# ['RESIDENCE', 'RESTAURANT', 'SCHOOL, PUBLIC, BUILDING', 'OTHER']

# %% [markdown]
# To modify the generated `categorical_labels`, assign a new value to `categorical_labels` or modify the existing one. The following example adds a missing label not found on the sample data to `categorical_labels`.

# %%
builder.categorical_labels.append('TOWNHOUSE')
builder.categorical_labels
# Out:
# ['RESIDENCE', 'RESTAURANT', 'SCHOOL, PUBLIC, BUILDING', 'OTHER', 'TOWNHOUSE']

# %% [markdown]
# Once the desired results are achieved, call `builder.to_dataflow` to get the new Dataflow with the encoded labels.

# %%
dflow = builder.to_dataflow()
dflow
# Out:
# Dataflow
#   name: crime-spring
#   parent_package_path: None
#   steps: [
#     Step {
#       type: Microsoft.DPrep.GetFilesBlock,
#     },
#     Step {
#       type: Microsoft.DPrep.ParseDelimitedBlock,
#     },
#     Step {
#       type: Microsoft.DPrep.DropColumnsBlock,
#     },
#     Step {
#       type: Microsoft.DPrep.OneHotEncodingBlock,
#     },
#     Step {
#       type: Microsoft.DPrep.OneHotEncodingBlock,
#     },
#   ]
