# %% [markdown]
# # Data Profile
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# A DataProfile collects summary statistics on each column of the data produced by a Dataflow. This can be used to:
# - Understand the input data.
# - Determine which columns might need further preparation.
# - Verify that data preparation operations produced the desired result.
#
# `Dataflow.get_profile()` executes the Dataflow, calculates profile information, and returns a newly constructed DataProfile.

# %%
import azureml.dataprep as dprep

dflow = dprep.auto_read_file('../data/crime-spring.csv')

profile = dflow.get_profile()
profile
# Out:
# ColumnProfile
#     name: ID
#     type: FieldType.DECIMAL
#
#     min: 10498554.0
#     max: 10535059.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 10498554.0
#            1%: 10499178.0
#            5%: 10498554.0
#           25%: 10516598.0
#           50%: 10520942.0
#           75%: 10525877.0
#           95%: 10535059.0
#           99%: 10535059.0
#         99.9%: 10535059.0
#
#     mean: 10519452.7
#     std: 12302.744698733817
#     variance: 151357527.12222305
#     skewness: -0.49570086276209613
#     kurtosis: -1.0281385989557137
#
# ColumnProfile
#     name: Case Number
#     type: FieldType.STRING
#
#     min: HZ239907
#     max: HZ278872
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Date
#     type: FieldType.DATE
#
#     min: 2016-04-15 04:30:00+00:00
#     max: 2016-04-15 23:56:00+00:00
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Block
#     type: FieldType.STRING
#
#     min: 004XX S KILBOURN AVE
#     max: 113XX S PRAIRIE AVE
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: IUCR
#     type: FieldType.DECIMAL
#
#     min: 810.0
#     max: 1154.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 810.0
#            1%: 850.0
#            5%: 810.0
#           25%: 890.0
#           50%: 1136.0
#           75%: 1153.0
#           95%: 1154.0
#           99%: 1154.0
#         99.9%: 1154.0
#
#     mean: 1058.5
#     std: 137.28498339828238
#     variance: 18847.16666666667
#     skewness: -0.7855010464472876
#     kurtosis: -1.3543030114392651
#
# ColumnProfile
#     name: Primary Type
#     type: FieldType.STRING
#
#     min: DECEPTIVE PRACTICE
#     max: THEFT
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Description
#     type: FieldType.STRING
#
#     min: BOGUS CHECK
#     max: OVER $500
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Location Description
#     type: FieldType.STRING
#
#     min:
#     max: SCHOOL, PUBLIC, BUILDING
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1.0
#
#
# ColumnProfile
#     name: Arrest
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: False
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Domestic
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: False
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Beat
#     type: FieldType.DECIMAL
#
#     min: 531.0
#     max: 2433.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 531.0
#            1%: 531.0
#            5%: 531.0
#           25%: 614.0
#           50%: 1318.5
#           75%: 1911.0
#           95%: 2433.0
#           99%: 2433.0
#         99.9%: 2433.0
#
#     mean: 1371.0999999999995
#     std: 692.0939965062549
#     variance: 478994.10000000003
#     skewness: 0.10541837450761402
#     kurtosis: -1.606844154378177
#
# ColumnProfile
#     name: District
#     type: FieldType.DECIMAL
#
#     min: 5.0
#     max: 24.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 5.0
#            1%: 5.0
#            5%: 5.0
#           25%: 6.0
#           50%: 13.0
#           75%: 19.0
#           95%: 24.0
#           99%: 24.0
#         99.9%: 24.0
#
#     mean: 13.5
#     std: 6.948221195225277
#     variance: 48.27777777777778
#     skewness: 0.09301086578662468
#     kurtosis: -1.623245307954198
#
# ColumnProfile
#     name: Ward
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 48.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 5.0
#            5%: 1.0
#           25%: 9.0
#           50%: 22.5
#           75%: 40.0
#           95%: 48.0
#           99%: 48.0
#         99.9%: 48.0
#
#     mean: 24.5
#     std: 16.263455967290593
#     variance: 264.49999999999994
#     skewness: 0.17372265885779775
#     kurtosis: -1.5127073945561942
#
# ColumnProfile
#     name: Community Area
#     type: FieldType.DECIMAL
#
#     min: 4.0
#     max: 77.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 4.0
#            1%: 8.5
#            5%: 4.0
#           25%: 24.0
#           50%: 37.5
#           75%: 71.0
#           95%: 77.0
#           99%: 77.0
#         99.9%: 77.0
#
#     mean: 41.2
#     std: 26.636649772655556
#     variance: 709.5111111111112
#     skewness: 0.11215705142047812
#     kurtosis: -1.7337878413444787
#
# ColumnProfile
#     name: FBI Code
#     type: FieldType.DECIMAL
#
#     min: 6.0
#     max: 11.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 6.0
#            1%: 6.0
#            5%: 6.0
#           25%: 6.0
#           50%: 11.0
#           75%: 11.0
#           95%: 11.0
#           99%: 11.0
#         99.9%: 11.0
#
#     mean: 9.399999999999999
#     std: 2.3664319132398464
#     variance: 5.6000000000000005
#     skewness: -0.7026853946457094
#     kurtosis: -1.5958163265306127
#
# ColumnProfile
#     name: X Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1163094.0
#     max: 1183356.0
#     count: 10.0
#     missing_count: 7.0
#     not_missing_count: 3.0
#     percent_missing: 0.7
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1163094.0
#            1%: 1163094.0
#            5%: 1163094.0
#           25%: 1164014.5
#           50%: 1166776.0
#           75%: 1179211.0
#           95%: 1183356.0
#           99%: 1183356.0
#         99.9%: 1183356.0
#
#     mean: 1171075.3333333333
#     std: 10793.533310891913
#     variance: 116500361.33333333
#     skewness: 0.33512559800708785
#     kurtosis: -2.333333333333333
#
# ColumnProfile
#     name: Y Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1831503.0
#     max: 1908003.0
#     count: 10.0
#     missing_count: 7.0
#     not_missing_count: 3.0
#     percent_missing: 0.7
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1831503.0
#            1%: 1831503.0
#            5%: 1831503.0
#           25%: 1836140.5
#           50%: 1850053.0
#           75%: 1893515.5
#           95%: 1908003.0
#           99%: 1908003.0
#         99.9%: 1908003.0
#
#     mean: 1863186.3333333335
#     std: 39905.21060379626
#     variance: 1592425833.3333333
#     skewness: 0.2934651697313084
#     kurtosis: -2.333333333333333
#
# ColumnProfile
#     name: Year
#     type: FieldType.DECIMAL
#
#     min: 2016.0
#     max: 2016.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 2016.0
#            1%: 2016.0
#            5%: 2016.0
#           25%: 2016.0
#           50%: 2016.0
#           75%: 2016.0
#           95%: 2016.0
#           99%: 2016.0
#         99.9%: 2016.0
#
#     mean: 2016.0
#     std: 0.0
#     variance: 0.0
#     skewness: nan
#     kurtosis: nan
#
# ColumnProfile
#     name: Updated On
#     type: FieldType.DATE
#
#     min: 2016-05-11 15:48:00+00:00
#     max: 2016-05-27 15:45:00+00:00
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Latitude
#     type: FieldType.DECIMAL
#
#     min: 41.69283384
#     max: 41.90320604
#     count: 10.0
#     missing_count: 7.0
#     not_missing_count: 3.0
#     percent_missing: 0.7
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 41.69283384
#            1%: 41.69283384
#            5%: 41.69283384
#           25%: 41.7056521225
#           50%: 41.74410697
#           75%: 41.8634312725
#           95%: 41.90320604
#           99%: 41.90320604
#         99.9%: 41.90320604
#
#     mean: 41.78004895
#     std: 0.10969496377660458
#     variance: 0.01203298507795059
#     skewness: 0.2924779180045832
#     kurtosis: -2.3333333333333335
#
# ColumnProfile
#     name: Longitude
#     type: FieldType.DECIMAL
#
#     min: -87.67636193
#     max: -87.60431945
#     count: 10.0
#     missing_count: 7.0
#     not_missing_count: 3.0
#     percent_missing: 0.7
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: -87.67636193
#            1%: -87.67636193
#            5%: -87.67636193
#           25%: -87.67339502
#           50%: -87.66449429
#           75%: -87.61936316
#           95%: -87.60431945
#           99%: -87.60431945
#         99.9%: -87.60431945
#
#     mean: -87.64839189
#     std: 0.038626353639159526
#     variance: 0.0014919951954574125
#     skewness: 0.34442895695673914
#     kurtosis: -2.3333333333333335
#
# ColumnProfile
#     name: Location
#     type: FieldType.STRING
#
#     min:
#     max: (41.903206037, -87.676361925)
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 7.0

# %% [markdown]
# A DataProfile contains a collection of ColumnProfiles, indexed by column name. Each ColumnProfile has attributes for the calculated column statistics. For non-numeric columns, profiles include only basic statistics like min, max, and error count. For numeric columns, profiles also include statistical moments and estimated quantiles.

# %%
profile.columns['Beat']
# Out:
# ColumnProfile
#     name: Beat
#     type: FieldType.DECIMAL
#
#     min: 531.0
#     max: 2433.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 531.0
#            1%: 531.0
#            5%: 531.0
#           25%: 614.0
#           50%: 1318.5
#           75%: 1911.0
#           95%: 2433.0
#           99%: 2433.0
#         99.9%: 2433.0
#
#     mean: 1371.0999999999995
#     std: 692.0939965062549
#     variance: 478994.10000000003
#     skewness: 0.10541837450761402
#     kurtosis: -1.606844154378177

# %% [markdown]
# You can also extract and filter data from profiles by using list and dict comprehensions.

# %%
variances = [c.variance for c in profile.columns.values() if c.variance]
variances
# Out:
# [151357527.12222305,
#  18847.16666666667,
#  478994.10000000003,
#  48.27777777777778,
#  264.49999999999994,
#  709.5111111111112,
#  5.6000000000000005,
#  116500361.33333333,
#  1592425833.3333333,
#  0.01203298507795059,
#  0.0014919951954574125]

# %%
column_types = {c.name: c.type for c in profile.columns.values()}
column_types
# Out:
# {'Arrest': <FieldType.BOOLEAN: 1>,
#  'Beat': <FieldType.DECIMAL: 3>,
#  'Block': <FieldType.STRING: 0>,
#  'Case Number': <FieldType.STRING: 0>,
#  'Community Area': <FieldType.DECIMAL: 3>,
#  'Date': <FieldType.DATE: 4>,
#  'Description': <FieldType.STRING: 0>,
#  'District': <FieldType.DECIMAL: 3>,
#  'Domestic': <FieldType.BOOLEAN: 1>,
#  'FBI Code': <FieldType.DECIMAL: 3>,
#  'ID': <FieldType.DECIMAL: 3>,
#  'IUCR': <FieldType.DECIMAL: 3>,
#  'Latitude': <FieldType.DECIMAL: 3>,
#  'Location': <FieldType.STRING: 0>,
#  'Location Description': <FieldType.STRING: 0>,
#  'Longitude': <FieldType.DECIMAL: 3>,
#  'Primary Type': <FieldType.STRING: 0>,
#  'Updated On': <FieldType.DATE: 4>,
#  'Ward': <FieldType.DECIMAL: 3>,
#  'X Coordinate': <FieldType.DECIMAL: 3>,
#  'Y Coordinate': <FieldType.DECIMAL: 3>,
#  'Year': <FieldType.DECIMAL: 3>}

# %% [markdown]
# If a column has fewer than a thousand unique values, its ColumnProfile contains a summary of values with their respective counts.

# %%
profile.columns['Primary Type'].value_counts
# Out:
# [ValueCountEntry(value='DECEPTIVE PRACTICE', count=7),
#  ValueCountEntry(value='THEFT', count=3)]

# %% [markdown]
# Numeric ColumnProfiles include an estimated histogram of the data.

# %%
profile.columns['District'].histogram
# Out:
# [HistogramBucket(lower_bound=5.0, upper_bound=6.9, count=2.6800000000000006),
#  HistogramBucket(lower_bound=6.9, upper_bound=8.8, count=0.37999999999999945),
#  HistogramBucket(lower_bound=8.8, upper_bound=10.7, count=0.379999999999999),
#  HistogramBucket(lower_bound=10.7, upper_bound=12.6, count=1.3600000000000008),
#  HistogramBucket(lower_bound=12.6, upper_bound=14.5, count=0.8666666666666671),
#  HistogramBucket(lower_bound=14.5, upper_bound=16.4, count=0.6333333333333329),
#  HistogramBucket(lower_bound=16.4, upper_bound=18.299999999999997, count=0.8499999999999988),
#  HistogramBucket(lower_bound=18.299999999999997, upper_bound=20.2, count=0.7500000000000009),
#  HistogramBucket(lower_bound=20.2, upper_bound=22.099999999999998, count=0.6500000000000012),
#  HistogramBucket(lower_bound=22.099999999999998, upper_bound=24.0, count=1.4499999999999993)]

# %% [markdown]
# For columns containing data of mixed types, the ColumnProfile also provides counts of each type.

# %%
profile.columns['X Coordinate'].type_counts
# Out:
# [TypeCountEntry(type=<FieldType.NULL: 7>, count=7),
#  TypeCountEntry(type=<FieldType.DECIMAL: 3>, count=3)]
