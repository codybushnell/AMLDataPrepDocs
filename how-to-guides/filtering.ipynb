# %% [markdown]
# # Filtering
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# Azure ML Data Prep has the ability to filter out columns or rows using `Dataflow.drop_columns` or `Dataflow.filter`.

# %%
# initial set up
import azureml.dataprep as dprep
from datetime import datetime
dflow = dprep.read_csv(path='../data/crime-spring.csv')
dflow.head(5)
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Filtering columns

# %% [markdown]
# To filter columns, use `Dataflow.drop_columns`. This method takes a list of columns to drop or a more complex argument called `ColumnSelector`.

# %% [markdown]
# ### Filtering columns with list of strings

# %% [markdown]
# In this example, `drop_columns` takes a list of strings. Each string should exactly match the desired column to drop.

# %%
dflow = dflow.drop_columns(['ID', 'Location Description', 'Ward', 'Community Area', 'FBI Code'])
dflow.head(5)
# Out:
#   Case Number             Date                   Block  IUCR  \
# 0    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description Arrest  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300  FALSE
# 1               THEFT                            FROM BUILDING  FALSE
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER  FALSE
# 3  DECEPTIVE PRACTICE                                  FORGERY  FALSE
# 4               THEFT                            FROM BUILDING  FALSE
#
#   Domestic  Beat District X Coordinate Y Coordinate  Year       Updated On  \
# 0    FALSE   531        5      1183356      1831503  2016  5/11/2016 15:48
# 1    FALSE   614        6      1166776      1850053  2016  5/12/2016 15:48
# 2    FALSE  2211       22                            2016  5/12/2016 15:50
# 3    FALSE   531        5                            2016  5/13/2016 15:51
# 4    FALSE  1712       17                            2016  5/25/2016 15:59
#
#       Latitude     Longitude                       Location
# 0  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2
# 3
# 4

# %% [markdown]
# ### Filtering columns with regex

# %% [markdown]
# Alternatively, a `ColumnSelector` can be used to drop columns that match a regex expression. In this example, we drop all the columns that match the expression `Column*|.*longitud|.*latitude`.

# %%
dflow = dflow.drop_columns(dprep.ColumnSelector('Column*|.*longitud|.*latitude', True, True))
dflow.head(5)
# Out:
#   Case Number             Date                   Block  IUCR  \
# 0    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description Arrest  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300  FALSE
# 1               THEFT                            FROM BUILDING  FALSE
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER  FALSE
# 3  DECEPTIVE PRACTICE                                  FORGERY  FALSE
# 4               THEFT                            FROM BUILDING  FALSE
#
#   Domestic  Beat District X Coordinate Y Coordinate  Year       Updated On  \
# 0    FALSE   531        5      1183356      1831503  2016  5/11/2016 15:48
# 1    FALSE   614        6      1166776      1850053  2016  5/12/2016 15:48
# 2    FALSE  2211       22                            2016  5/12/2016 15:50
# 3    FALSE   531        5                            2016  5/13/2016 15:51
# 4    FALSE  1712       17                            2016  5/25/2016 15:59
#
#                         Location
# 0   (41.692833841, -87.60431945)
# 1  (41.744106973, -87.664494285)
# 2
# 3
# 4

# %% [markdown]
# ## Filtering rows

# %% [markdown]
# To filter rows, use `DataFlow.filter`. This method takes an `Expression` as an argument, and returns a new dataflow with the rows in which the expression evaluates to `True`. Expressions are built by indexing the `Dataflow` with a column name (`dataflow['myColumn']`) and regular operators (`>`, `<`, `>=`, `<=`, `==`, `!=`).

# %% [markdown]
# ### Filtering rows with simple expressions

# %% [markdown]
# Index into the Dataflow specifying the column name as a string argument `dataflow['column_name']` and in combination with one of the following standard operators `>, <, >=, <=, ==, !=`, build an expression such as `dataflow['District'] > 9`.  Finally, pass the built expression into the `Dataflow.filter` function.
#
# In this example, `dataflow.filter(dataflow['District'] > 9)` returns a new dataflow with the rows in which the value of "District" is greater than '10'
#
# *Note that "District" is first converted to numeric, which allows us to build an expression comparing it against other numeric values.*

# %%
dflow = dflow.to_number(['District'])
dflow = dflow.filter(dflow['District'] > 9)
dflow.head(5)
# Out:
#   Case Number             Date                   Block  IUCR  \
# 0    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 1    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
# 2    HZ278872   4/15/2016 4:30    004XX S KILBOURN AVE   810
# 3    HZ240778  4/15/2016 10:00   010XX N MILWAUKEE AVE  1152
# 4    HZ264802  4/15/2016 16:00     019XX W DIVISION ST  1110
#
#          Primary Type                              Description Arrest  \
# 0  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER  FALSE
# 1               THEFT                            FROM BUILDING  FALSE
# 2               THEFT                                OVER $500  FALSE
# 3  DECEPTIVE PRACTICE                    ILLEGAL USE CASH CARD  FALSE
# 4  DECEPTIVE PRACTICE                              BOGUS CHECK  FALSE
#
#   Domestic  Beat  District X Coordinate Y Coordinate  Year       Updated On  \
# 0    FALSE  2211      22.0                            2016  5/12/2016 15:50
# 1    FALSE  1712      17.0                            2016  5/25/2016 15:59
# 2    FALSE  1131      11.0                            2016  5/25/2016 15:59
# 3    FALSE  1213      12.0                            2016  5/27/2016 15:45
# 4    FALSE  1424      14.0      1163094      1908003  2016  5/16/2016 15:48
#
#                         Location
# 0
# 1
# 2
# 3
# 4  (41.903206037, -87.676361925)

# %% [markdown]
# ### Filtering rows with complex expressions

# %% [markdown]
# To filter using complex expressions, combine one or more simple expressions with the operators `&`, `|`, and `~`. Please note that the precedence of these operators is lower than that of the comparison operators; therefore, you'll need to use parentheses to group clauses together.
#
# In this example, `Dataflow.filter` returns a new dataflow with the rows in which "Primary Type" equals 'DECEPTIVE PRACTICE' and "District" is greater than or equal to '10'.

# %%
dflow = dflow.to_number(['District'])
dflow = dflow.filter((dflow['Primary Type'] == 'DECEPTIVE PRACTICE') & (dflow['District'] >= 10))
dflow.head(5)
# Out:
#   Case Number             Date                   Block  IUCR  \
# 0    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 1    HZ240778  4/15/2016 10:00   010XX N MILWAUKEE AVE  1152
# 2    HZ264802  4/15/2016 16:00     019XX W DIVISION ST  1110
# 3    HZ265911   4/15/2016 8:00     061XX N SHERIDAN RD  1153
# 4    HZ268138  4/15/2016 15:00    023XX W EASTWOOD AVE  1153
#
#          Primary Type                              Description Arrest  \
# 0  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER  FALSE
# 1  DECEPTIVE PRACTICE                    ILLEGAL USE CASH CARD  FALSE
# 2  DECEPTIVE PRACTICE                              BOGUS CHECK  FALSE
# 3  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300  FALSE
# 4  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300  FALSE
#
#   Domestic  Beat  District X Coordinate Y Coordinate  Year       Updated On  \
# 0    FALSE  2211      22.0                            2016  5/12/2016 15:50
# 1    FALSE  1213      12.0                            2016  5/27/2016 15:45
# 2    FALSE  1424      14.0      1163094      1908003  2016  5/16/2016 15:48
# 3    FALSE  2433      24.0                            2016  5/16/2016 15:50
# 4    FALSE  1911      19.0                            2016  5/18/2016 15:50
#
#                         Location
# 0
# 1
# 2  (41.903206037, -87.676361925)
# 3
# 4

# %% [markdown]
# It is also possible to filter rows combining more than one expression builder to create a nested expression.
#
# *Note that `'Date'` and `'Updated On'` are first converted to datetime, which allows us to build an expression comparing it against other datetime values.*

# %%
dflow = dflow.to_datetime(['Date', 'Updated On'], ['%Y-%m-%d %H:%M:%S'])
dflow = dflow.to_number(['District', 'Y Coordinate'])
comparison_date = datetime(2016,4,13)
dflow = dflow.filter(
    ((dflow['Date'] > comparison_date) | (dflow['Updated On'] > comparison_date))
    | ((dflow['Y Coordinate'] > 1900000) & (dflow['District'] > 10.0)))
dflow.head(5)
# Out:
#   Case Number                                               Date  \
# 0    HZ264802  azureml.dataprep.native.DataPrepError("'Micros...
#
#                  Block  IUCR        Primary Type  Description Arrest Domestic  \
# 0  019XX W DIVISION ST  1110  DECEPTIVE PRACTICE  BOGUS CHECK  FALSE    FALSE
#
#    Beat  District X Coordinate  Y Coordinate  Year  \
# 0  1424      14.0      1163094     1908003.0  2016
#
#                                           Updated On  \
# 0  azureml.dataprep.native.DataPrepError("'Micros...
#
#                         Location
# 0  (41.903206037, -87.676361925)
