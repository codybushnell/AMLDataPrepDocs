# %% [markdown]
# # Column Manipulations
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.<br>
#
# Azure ML Data Prep has many methods for manipulating columns, including basic CUD operations and several other more complex manipulations.
#
# This notebook will focus primarily on data-agnostic operations. For all other column manipulation operations, we will link to their specific how-to guide.
#
# ## Table of Contents
# [ColumnSelector](#ColumnSelector)<br>
# [add_column](#add_columns)<br>
# [append_columns](#append_columns)<br>
# [drop_columns](#drop_columns)<br>
# [duplicate_column](#duplicate_column)<br>
# [fuzzy_group_column](#fuzzy_group_column)<br>
# [keep_columns](#keep_columns)<br>
# [map_column](#map_column)<br>
# [new_script_column](#new_script_column)<br>
# [rename_columns](#rename_columns)<br>

# %% [markdown]
# ## ColumnSelector
# `ColumnSelector` is a Data Prep class that allows us to select columns by name. The idea is to be able to describe columns generally instead of explicitly, using a search term or regex expression, with various options.
#
# Note that a `ColumnSelector` does not represent the columns they match themselves, but the selector of the described columns. Therefore if we use the same `ColumnSelector` on two different dataflows, we may get different results depending on the columns of each dataflow.
#
# Column manipulations that can utilize `ColumnSelector` will be noted in their respective sections in this book.

# %%
from azureml.dataprep import auto_read_file
dflow = auto_read_file(path='../data/crime-dirty.csv')
dflow.head(5)
# Out:
#            ID Case Number                    Date                Block   IUCR  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic              ...                Ward  Community Area  \
# 0  False    False              ...                41.0            10.0
# 1  False     True              ...                49.0             1.0
# 2  False     True              ...                 9.0            53.0
# 3  False    False              ...                37.0            25.0
# 4  False    False              ...                27.0            28.0
#
#    FBI Code  X Coordinate Y Coordinate    Year              Updated On  \
# 0        06     1129230.0    1933315.0  2015.0  07/12/2015 12:42:46 PM
# 1       08B     1167370.0    1946271.0  2015.0  07/12/2015 12:42:46 PM
# 2       08B           NaN          NaN  2015.0  07/12/2015 12:42:46 PM
# 3        05     1141721.0    1907465.0  2015.0  07/12/2015 12:42:46 PM
# 4        07     1168413.0    1901632.0  2015.0  07/12/2015 12:42:46 PM
#
#     Latitude  Longitude                       Location
# 0  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2        NaN        NaN
# 3  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %% [markdown]
# All parameters to a `ColumnSelector` are shown here for completeness. We will use `keep_columns` in our example, which will keep only the columns in the dataflow that we tell it to keep.
#
# In the below example, we match all columns with the letter 'i'. Because we set `ignore_case` to false and `match_whole_word` to false, then any column that contains 'i' or 'I' will be selected.

# %%
from azureml.dataprep import ColumnSelector
column_selector = ColumnSelector(term="i",
                                 use_regex=False,
                                 ignore_case=True,
                                 match_whole_word=False,
                                 invert=False)
dflow_selected = dflow.keep_columns(column_selector)
dflow_selected.head(5)
# Out:
#            ID   IUCR         Primary Type                 Description  \
# 0  10140490.0  820.0                THEFT              $500 AND UNDER
# 1  10139776.0  460.0              BATTERY                      SIMPLE
# 2  10140270.0  486.0              BATTERY     DOMESTIC BATTERY SIMPLE
# 3  10139885.0  610.0             BURGLARY              FORCIBLE ENTRY
# 4  10140379.0  930.0  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE
#
#   Location Description Domestic  District  Community Area FBI Code  \
# 0               STREET    False      16.0            10.0       06
# 1               STREET     True      24.0             1.0      08B
# 2               STREET     True       NaN            53.0      08B
# 3   SMALL RETAIL STORE    False      15.0            25.0       05
# 4               STREET    False      12.0            28.0       07
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  \
# 0     1129230.0     1933315.0  41.973309 -87.800175
# 1     1167370.0     1946271.0  42.008124 -87.659550
# 2           NaN           NaN        NaN        NaN
# 3     1141721.0     1907465.0  41.902152 -87.754883
# 4     1168413.0     1901632.0  41.885610 -87.657009
#
#                         Location
# 0  (41.973309466, -87.800174996)
# 1   (42.008124017, -87.65955018)
# 2
# 3  (41.902152027, -87.754883404)
# 4  (41.885610142, -87.657008701)

# %% [markdown]
# If we set `invert` to true, we get the opposite of what we matched earlier.

# %%
column_selector = ColumnSelector(term="i",
                                 use_regex=False,
                                 ignore_case=True,
                                 match_whole_word=False,
                                 invert=True)
dflow_selected = dflow.keep_columns(column_selector)
dflow_selected.head(5)
# Out:
#   Case Number                    Date                Block Arrest    Beat  \
# 0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  False  1613.0
# 1    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  False  2431.0
# 2    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  False   532.0
# 3    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  False  1531.0
# 4    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  False  1215.0
#
#    Ward    Year              Updated On
# 0  41.0  2015.0  07/12/2015 12:42:46 PM
# 1  49.0  2015.0  07/12/2015 12:42:46 PM
# 2   9.0  2015.0  07/12/2015 12:42:46 PM
# 3  37.0  2015.0  07/12/2015 12:42:46 PM
# 4  27.0  2015.0  07/12/2015 12:42:46 PM

# %% [markdown]
# If we change the search term to 'I' and set case sensitivity to true, we get only the handful of columns that contain an upper case 'I'.

# %%
column_selector = ColumnSelector(term="I",
                                 use_regex=False,
                                 ignore_case=False,
                                 match_whole_word=False,
                                 invert=False)
dflow_selected = dflow.keep_columns(column_selector)
dflow_selected.head(5)
# Out:
#            ID   IUCR FBI Code
# 0  10140490.0  820.0       06
# 1  10139776.0  460.0      08B
# 2  10140270.0  486.0      08B
# 3  10139885.0  610.0       05
# 4  10140379.0  930.0       07

# %% [markdown]
# And if we set `match_whole_word` to true, we get no results at all as there is no column called 'I'.

# %%
column_selector = ColumnSelector(term="I",
                                 use_regex=False,
                                 ignore_case=False,
                                 match_whole_word=True,
                                 invert=False)
dflow_selected = dflow.keep_columns(column_selector)
dflow_selected.head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Finally, the `use_regex` flag dictates whether or not to treat the search term as a regex. It can be combined still with the other options.
#
# Here we define all columns that begin with the capital letter 'I'.

# %%
column_selector = ColumnSelector(term="I.*",
                                 use_regex=True,
                                 ignore_case=True,
                                 match_whole_word=True,
                                 invert=False)
dflow_selected = dflow.keep_columns(column_selector)
dflow_selected.head(5)
# Out:
#            ID   IUCR
# 0  10140490.0  820.0
# 1  10139776.0  460.0
# 2  10140270.0  486.0
# 3  10139885.0  610.0
# 4  10140379.0  930.0

# %% [markdown]
# ## add_column

# %% [markdown]
# Please see [add-column-using-expression](add-column-using-expression.ipynb).

# %% [markdown]
# ## append_columns

# %% [markdown]
# Please see [append-columns-and-rows](append-columns-and-rows.ipynb).

# %% [markdown]
# ## drop_columns

# %% [markdown]
# Data Prep supports dropping columns one or more columns in a single statement. Supports `ColumnSelector`.

# %%
from azureml.dataprep import auto_read_file
dflow = auto_read_file(path='../data/crime-dirty.csv')
dflow.head(5)
# Out:
#            ID Case Number                    Date                Block   IUCR  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic              ...                Ward  Community Area  \
# 0  False    False              ...                41.0            10.0
# 1  False     True              ...                49.0             1.0
# 2  False     True              ...                 9.0            53.0
# 3  False    False              ...                37.0            25.0
# 4  False    False              ...                27.0            28.0
#
#    FBI Code  X Coordinate Y Coordinate    Year              Updated On  \
# 0        06     1129230.0    1933315.0  2015.0  07/12/2015 12:42:46 PM
# 1       08B     1167370.0    1946271.0  2015.0  07/12/2015 12:42:46 PM
# 2       08B           NaN          NaN  2015.0  07/12/2015 12:42:46 PM
# 3        05     1141721.0    1907465.0  2015.0  07/12/2015 12:42:46 PM
# 4        07     1168413.0    1901632.0  2015.0  07/12/2015 12:42:46 PM
#
#     Latitude  Longitude                       Location
# 0  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2        NaN        NaN
# 3  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %% [markdown]
# Note that there are 22 columns to begin with. We will now drop the 'ID' column and observe that the resulting dataflow contains 21 columns.

# %%
dflow_dropped = dflow.drop_columns('ID')
dflow_dropped.head(5)
# Out:
#   Case Number                    Date                Block   IUCR  \
# 0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  820.0
# 1    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  460.0
# 2    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  486.0
# 3    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  610.0
# 4    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic    Beat              ...                Ward  \
# 0  False    False  1613.0              ...                41.0
# 1  False     True  2431.0              ...                49.0
# 2  False     True   532.0              ...                 9.0
# 3  False    False  1531.0              ...                37.0
# 4  False    False  1215.0              ...                27.0
#
#    Community Area  FBI Code X Coordinate  Y Coordinate    Year  \
# 0            10.0        06    1129230.0     1933315.0  2015.0
# 1             1.0       08B    1167370.0     1946271.0  2015.0
# 2            53.0       08B          NaN           NaN  2015.0
# 3            25.0        05    1141721.0     1907465.0  2015.0
# 4            28.0        07    1168413.0     1901632.0  2015.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  07/12/2015 12:42:46 PM  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  07/12/2015 12:42:46 PM  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2  07/12/2015 12:42:46 PM        NaN        NaN
# 3  07/12/2015 12:42:46 PM  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  07/12/2015 12:42:46 PM  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 21 columns]

# %% [markdown]
# We can also drop more than one column at once by passing a list of column names.

# %%
dflow_dropped = dflow_dropped.drop_columns(['IUCR', 'Description'])
dflow_dropped.head(5)
# Out:
#   Case Number                    Date                Block  \
# 0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE
# 1    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE
# 2    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE
# 3    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST
# 4    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST
#
#           Primary Type Location Description Arrest Domestic    Beat  District  \
# 0                THEFT               STREET  False    False  1613.0      16.0
# 1              BATTERY               STREET  False     True  2431.0      24.0
# 2              BATTERY               STREET  False     True   532.0       NaN
# 3             BURGLARY   SMALL RETAIL STORE  False    False  1531.0      15.0
# 4  MOTOR VEHICLE THEFT               STREET  False    False  1215.0      12.0
#
#    Ward  Community Area FBI Code  X Coordinate  Y Coordinate    Year  \
# 0  41.0            10.0       06     1129230.0     1933315.0  2015.0
# 1  49.0             1.0      08B     1167370.0     1946271.0  2015.0
# 2   9.0            53.0      08B           NaN           NaN  2015.0
# 3  37.0            25.0       05     1141721.0     1907465.0  2015.0
# 4  27.0            28.0       07     1168413.0     1901632.0  2015.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  07/12/2015 12:42:46 PM  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  07/12/2015 12:42:46 PM  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2  07/12/2015 12:42:46 PM        NaN        NaN
# 3  07/12/2015 12:42:46 PM  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  07/12/2015 12:42:46 PM  41.885610 -87.657009  (41.885610142, -87.657008701)

# %% [markdown]
# ## duplicate_column

# %% [markdown]
# Data Prep supports duplicating columns one or more columns in a single statement.
#
# Duplicated columns are placed to the immediate right of their source column.

# %%
from azureml.dataprep import auto_read_file
dflow = auto_read_file(path='../data/crime-dirty.csv')
dflow.head(5)
# Out:
#            ID Case Number                    Date                Block   IUCR  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic              ...                Ward  Community Area  \
# 0  False    False              ...                41.0            10.0
# 1  False     True              ...                49.0             1.0
# 2  False     True              ...                 9.0            53.0
# 3  False    False              ...                37.0            25.0
# 4  False    False              ...                27.0            28.0
#
#    FBI Code  X Coordinate Y Coordinate    Year              Updated On  \
# 0        06     1129230.0    1933315.0  2015.0  07/12/2015 12:42:46 PM
# 1       08B     1167370.0    1946271.0  2015.0  07/12/2015 12:42:46 PM
# 2       08B           NaN          NaN  2015.0  07/12/2015 12:42:46 PM
# 3        05     1141721.0    1907465.0  2015.0  07/12/2015 12:42:46 PM
# 4        07     1168413.0    1901632.0  2015.0  07/12/2015 12:42:46 PM
#
#     Latitude  Longitude                       Location
# 0  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2        NaN        NaN
# 3  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %% [markdown]
# We decide which column(s) to duplicate and what the new column name(s) should be with a key value pairing (dictionary).

# %%
dflow_dupe = dflow.duplicate_column({'ID': 'ID2', 'IUCR': 'IUCR_Clone'})
dflow_dupe.head(5)
# Out:
#            ID         ID2 Case Number                    Date  \
# 0  10140490.0  10140490.0    HY329907  07/05/2015 11:50:00 PM
# 1  10139776.0  10139776.0    HY329265  07/05/2015 11:30:00 PM
# 2  10140270.0  10140270.0    HY329253  07/05/2015 11:20:00 PM
# 3  10139885.0  10139885.0    HY329308  07/05/2015 11:19:00 PM
# 4  10140379.0  10140379.0    HY329556  07/05/2015 11:00:00 PM
#
#                  Block   IUCR  IUCR_Clone         Primary Type  \
# 0  050XX N NEWLAND AVE  820.0       820.0                THEFT
# 1    011XX W MORSE AVE  460.0       460.0              BATTERY
# 2    121XX S FRONT AVE  486.0       486.0              BATTERY
# 3  051XX W DIVISION ST  610.0       610.0             BURGLARY
# 4      012XX W LAKE ST  930.0       930.0  MOTOR VEHICLE THEFT
#
#                   Description Location Description  \
# 0              $500 AND UNDER               STREET
# 1                      SIMPLE               STREET
# 2     DOMESTIC BATTERY SIMPLE               STREET
# 3              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#                ...                Ward Community Area  FBI Code  X Coordinate  \
# 0              ...                41.0           10.0        06     1129230.0
# 1              ...                49.0            1.0       08B     1167370.0
# 2              ...                 9.0           53.0       08B           NaN
# 3              ...                37.0           25.0        05     1141721.0
# 4              ...                27.0           28.0        07     1168413.0
#
#    Y Coordinate    Year              Updated On   Latitude  Longitude  \
# 0     1933315.0  2015.0  07/12/2015 12:42:46 PM  41.973309 -87.800175
# 1     1946271.0  2015.0  07/12/2015 12:42:46 PM  42.008124 -87.659550
# 2           NaN  2015.0  07/12/2015 12:42:46 PM        NaN        NaN
# 3     1907465.0  2015.0  07/12/2015 12:42:46 PM  41.902152 -87.754883
# 4     1901632.0  2015.0  07/12/2015 12:42:46 PM  41.885610 -87.657009
#
#                         Location
# 0  (41.973309466, -87.800174996)
# 1   (42.008124017, -87.65955018)
# 2
# 3  (41.902152027, -87.754883404)
# 4  (41.885610142, -87.657008701)
#
# [5 rows x 24 columns]

# %% [markdown]
# ## fuzzy_group_column

# %% [markdown]
# Please see [fuzzy-group](fuzzy-group.ipynb).

# %% [markdown]
# ## keep_columns

# %% [markdown]
# Data Prep supports keeping one or more columns in a single statement. The resulting dataflow will contain only the column(s) specified; dropping all the other columns. Supports `ColumnSelector`.

# %%
from azureml.dataprep import auto_read_file
dflow = auto_read_file(path='../data/crime-dirty.csv')
dflow.head(5)
# Out:
#            ID Case Number                    Date                Block   IUCR  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic              ...                Ward  Community Area  \
# 0  False    False              ...                41.0            10.0
# 1  False     True              ...                49.0             1.0
# 2  False     True              ...                 9.0            53.0
# 3  False    False              ...                37.0            25.0
# 4  False    False              ...                27.0            28.0
#
#    FBI Code  X Coordinate Y Coordinate    Year              Updated On  \
# 0        06     1129230.0    1933315.0  2015.0  07/12/2015 12:42:46 PM
# 1       08B     1167370.0    1946271.0  2015.0  07/12/2015 12:42:46 PM
# 2       08B           NaN          NaN  2015.0  07/12/2015 12:42:46 PM
# 3        05     1141721.0    1907465.0  2015.0  07/12/2015 12:42:46 PM
# 4        07     1168413.0    1901632.0  2015.0  07/12/2015 12:42:46 PM
#
#     Latitude  Longitude                       Location
# 0  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2        NaN        NaN
# 3  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %%
dflow_keep = dflow.keep_columns(['ID', 'Date', 'Description'])
dflow_keep.head(5)
# Out:
#            ID                    Date                 Description
# 0  10140490.0  07/05/2015 11:50:00 PM              $500 AND UNDER
# 1  10139776.0  07/05/2015 11:30:00 PM                      SIMPLE
# 2  10140270.0  07/05/2015 11:20:00 PM     DOMESTIC BATTERY SIMPLE
# 3  10139885.0  07/05/2015 11:19:00 PM              FORCIBLE ENTRY
# 4  10140379.0  07/05/2015 11:00:00 PM  THEFT/RECOVERY: AUTOMOBILE

# %% [markdown]
# Similar to `drop_columns`, we can pass a single column name or a list of them.

# %%
dflow_keep = dflow_keep.keep_columns('ID')
dflow_keep.head(5)
# Out:
#            ID
# 0  10140490.0
# 1  10139776.0
# 2  10140270.0
# 3  10139885.0
# 4  10140379.0

# %% [markdown]
# ## map_column

# %% [markdown]
# Data Prep supports string mapping. For a column containing strings, we can provide specific mappings from an original value to a new value, and then produce a new column that contains the mapped values.
#
# The mapped columns are placed to the immediate right of their source column.

# %%
from azureml.dataprep import auto_read_file
dflow = auto_read_file(path='../data/crime-dirty.csv')
dflow.head(5)
# Out:
#            ID Case Number                    Date                Block   IUCR  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic              ...                Ward  Community Area  \
# 0  False    False              ...                41.0            10.0
# 1  False     True              ...                49.0             1.0
# 2  False     True              ...                 9.0            53.0
# 3  False    False              ...                37.0            25.0
# 4  False    False              ...                27.0            28.0
#
#    FBI Code  X Coordinate Y Coordinate    Year              Updated On  \
# 0        06     1129230.0    1933315.0  2015.0  07/12/2015 12:42:46 PM
# 1       08B     1167370.0    1946271.0  2015.0  07/12/2015 12:42:46 PM
# 2       08B           NaN          NaN  2015.0  07/12/2015 12:42:46 PM
# 3        05     1141721.0    1907465.0  2015.0  07/12/2015 12:42:46 PM
# 4        07     1168413.0    1901632.0  2015.0  07/12/2015 12:42:46 PM
#
#     Latitude  Longitude                       Location
# 0  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2        NaN        NaN
# 3  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %%
from azureml.dataprep import ReplacementsValue
replacements = [ReplacementsValue('THEFT', 'THEFT2'), ReplacementsValue('BATTERY', 'BATTERY!!!')]
dflow_mapped = dflow.map_column(column='Primary Type', 
                                new_column_id='Primary Type V2',
                                replacements=replacements)
dflow_mapped.head(5)
# Out:
#            ID Case Number                    Date                Block   IUCR  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  930.0
#
#           Primary Type      Primary Type V2                 Description  \
# 0                THEFT               THEFT2              $500 AND UNDER
# 1              BATTERY           BATTERY!!!                      SIMPLE
# 2              BATTERY           BATTERY!!!     DOMESTIC BATTERY SIMPLE
# 3             BURGLARY             BURGLARY              FORCIBLE ENTRY
# 4  MOTOR VEHICLE THEFT  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE
#
#   Location Description Arrest              ...                Ward  \
# 0               STREET  False              ...                41.0
# 1               STREET  False              ...                49.0
# 2               STREET  False              ...                 9.0
# 3   SMALL RETAIL STORE  False              ...                37.0
# 4               STREET  False              ...                27.0
#
#    Community Area  FBI Code  X Coordinate  Y Coordinate    Year  \
# 0            10.0        06     1129230.0     1933315.0  2015.0
# 1             1.0       08B     1167370.0     1946271.0  2015.0
# 2            53.0       08B           NaN           NaN  2015.0
# 3            25.0        05     1141721.0     1907465.0  2015.0
# 4            28.0        07     1168413.0     1901632.0  2015.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  07/12/2015 12:42:46 PM  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  07/12/2015 12:42:46 PM  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2  07/12/2015 12:42:46 PM        NaN        NaN
# 3  07/12/2015 12:42:46 PM  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  07/12/2015 12:42:46 PM  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 23 columns]

# %% [markdown]
# ## new_script_column

# %% [markdown]
# Please see [custom-python-transforms](custom-python-transforms.ipynb).

# %% [markdown]
# ## rename_columns

# %% [markdown]
# Data Prep supports renaming one or more columns in a single statement.

# %%
from azureml.dataprep import auto_read_file
dflow = auto_read_file(path='../data/crime-dirty.csv')
dflow.head(5)
# Out:
#            ID Case Number                    Date                Block   IUCR  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  820.0
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  460.0
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  486.0
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  610.0
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  930.0
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic              ...                Ward  Community Area  \
# 0  False    False              ...                41.0            10.0
# 1  False     True              ...                49.0             1.0
# 2  False     True              ...                 9.0            53.0
# 3  False    False              ...                37.0            25.0
# 4  False    False              ...                27.0            28.0
#
#    FBI Code  X Coordinate Y Coordinate    Year              Updated On  \
# 0        06     1129230.0    1933315.0  2015.0  07/12/2015 12:42:46 PM
# 1       08B     1167370.0    1946271.0  2015.0  07/12/2015 12:42:46 PM
# 2       08B           NaN          NaN  2015.0  07/12/2015 12:42:46 PM
# 3        05     1141721.0    1907465.0  2015.0  07/12/2015 12:42:46 PM
# 4        07     1168413.0    1901632.0  2015.0  07/12/2015 12:42:46 PM
#
#     Latitude  Longitude                       Location
# 0  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2        NaN        NaN
# 3  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %% [markdown]
# We decide which column(s) to rename and what the new column name(s) should be with a key value pairing (dictionary).

# %%
dflow_renamed = dflow.rename_columns({'ID': 'ID2', 'IUCR': 'IUCR_Clone'})
dflow_renamed.head(5)
# Out:
#           ID2 Case Number                    Date                Block  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST
#
#    IUCR_Clone         Primary Type                 Description  \
# 0       820.0                THEFT              $500 AND UNDER
# 1       460.0              BATTERY                      SIMPLE
# 2       486.0              BATTERY     DOMESTIC BATTERY SIMPLE
# 3       610.0             BURGLARY              FORCIBLE ENTRY
# 4       930.0  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE
#
#   Location Description Arrest Domestic              ...                Ward  \
# 0               STREET  False    False              ...                41.0
# 1               STREET  False     True              ...                49.0
# 2               STREET  False     True              ...                 9.0
# 3   SMALL RETAIL STORE  False    False              ...                37.0
# 4               STREET  False    False              ...                27.0
#
#    Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0            10.0        06     1129230.0    1933315.0  2015.0
# 1             1.0       08B     1167370.0    1946271.0  2015.0
# 2            53.0       08B           NaN          NaN  2015.0
# 3            25.0        05     1141721.0    1907465.0  2015.0
# 4            28.0        07     1168413.0    1901632.0  2015.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  07/12/2015 12:42:46 PM  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  07/12/2015 12:42:46 PM  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2  07/12/2015 12:42:46 PM        NaN        NaN
# 3  07/12/2015 12:42:46 PM  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  07/12/2015 12:42:46 PM  41.885610 -87.657009  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]
