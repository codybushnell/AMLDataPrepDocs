# %% [markdown]
# # Replace DataSource Reference
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# A common practice when performing DataPrep is to build up a script or set of cleaning operations on a smaller example file locally. This is quicker and easier than dealing with large amounts of data initially.
#
# After building a Dataflow that performs the desired steps, it's time to run it against the larger dataset, which may be stored in the cloud, or even locally just in a different file. This is where we can use `Dataflow.replace_datasource` to get a Dataflow identical to the one built on the small data, but referencing the newly specified DataSource.

# %%
import azureml.dataprep as dprep

dflow = dprep.read_csv('../data/crime-spring.csv')
df = dflow.to_pandas_dataframe()
df
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
# 5  10535059    HZ278872   4/15/2016 4:30    004XX S KILBOURN AVE   810
# 6  10499802    HZ240778  4/15/2016 10:00   010XX N MILWAUKEE AVE  1152
# 7  10522293    HZ264802  4/15/2016 16:00     019XX W DIVISION ST  1110
# 8  10523111    HZ265911   4/15/2016 8:00     061XX N SHERIDAN RD  1153
# 9  10525877    HZ268138  4/15/2016 15:00    023XX W EASTWOOD AVE  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
# 5               THEFT                                OVER $500
# 6  DECEPTIVE PRACTICE                    ILLEGAL USE CASH CARD
# 7  DECEPTIVE PRACTICE                              BOGUS CHECK
# 8  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 9  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
# 5                 RESIDENCE  FALSE    FALSE              ...
# 6                 RESIDENCE  FALSE    FALSE              ...
# 7                RESTAURANT  FALSE    FALSE              ...
# 8                 RESIDENCE  FALSE    FALSE              ...
# 9                            FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
# 5   24             26        6                            2016
# 6   27             24       11                            2016
# 7    1             24       11      1163094      1908003  2016
# 8   48             77       11                            2016
# 9   47              4       11                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
# 5  5/25/2016 15:59
# 6  5/27/2016 15:45
# 7  5/16/2016 15:48  41.90320604  -87.67636193  (41.903206037, -87.676361925)
# 8  5/16/2016 15:50
# 9  5/18/2016 15:50
#
# [10 rows x 22 columns]

# %% [markdown]
# Here we have the first 10 rows of a dataset called 'Crime'. The original dataset is over 100MB (admittedly not that large of a dataset but this is just an example).
#
# We'll perform a few cleaning operations.

# %%
dflow_dropped = dflow.drop_columns(['Location', 'Updated On', 'X Coordinate', 'Y Coordinate', 'Description'])
sctb = dflow_dropped.builders.set_column_types()
sctb.learn(inference_arguments=dprep.InferenceArguments(day_first=False))
dflow_typed = sctb.to_dataflow()
dflow_typed.head(5)
# Out:
#            ID Case Number                Date                   Block    IUCR  \
# 0  10498554.0    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598.0    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196.0    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591.0    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446.0    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#          Primary Type      Location Description Arrest Domestic    Beat  \
# 0  DECEPTIVE PRACTICE                     OTHER  False    False   531.0
# 1               THEFT                 RESIDENCE  False    False   614.0
# 2  DECEPTIVE PRACTICE                 RESIDENCE  False    False  2211.0
# 3  DECEPTIVE PRACTICE                 RESIDENCE  False    False   531.0
# 4               THEFT  SCHOOL, PUBLIC, BUILDING  False    False  1712.0
#
#    District  Ward  Community Area  FBI Code    Year   Latitude  Longitude
# 0       5.0   9.0            50.0      11.0  2016.0  41.692834 -87.604319
# 1       6.0  21.0            71.0       6.0  2016.0  41.744107 -87.664494
# 2      22.0  19.0            74.0      11.0  2016.0        NaN        NaN
# 3       5.0   9.0            49.0      10.0  2016.0        NaN        NaN
# 4      17.0  40.0            13.0       6.0  2016.0        NaN        NaN

# %% [markdown]
# Now that we have a Dataflow with all our desired steps, we're ready to run against the 'full' dataset stored in Azure Blob.
# All we need to do is pass the BlobDataSource into `replace_datasource` and we'll get back an identical Dataflow with the new DataSource substituted in.

# %%
dflow_replaced = dflow_typed.replace_datasource(dprep.BlobDataSource('https://dpreptestfiles.blob.core.windows.net/testfiles/crime0.csv'))

# %% [markdown]
# 'replaced_dflow' will now pull data from the 168MB (729734 rows) version of Crime0.csv stored in Azure Blob!
#
# NOTE: Dataflows can also be created by referencing a different Dataflow. Instead of using `replace_datasource`, there is a corresponding `replace_reference` method.
#
# We should be careful now since pulling all that data down and putting it in a pandas dataframe isn't an ideal way to inspect the result of our Dataflow. So instead, to see that our steps are being applied to all the new data, we can add a `take_sample` step, which will select records at random (based on a given probability) to be returned.
#
# The probability below takes the ~730000 rows down to a more inspectable ~73, though the number will vary each time `to_pandas_dataframe()` is run, since they are being randomly selected based on the probability.

# %%
dflow_random_sample= dflow_replaced.take_sample(probability=0.0001)
sample = dflow_random_sample.to_pandas_dataframe()
sample
# Out:
#            ID Case Number  Date                      Block    IUCR  \
# 0   9882198.0    HX533372  None          024XX W CERMAK RD   560.0
# 1   9625971.0    HX276498  None           015XX W 111TH ST   460.0
# 2   9358491.0    HW501910  None       001XX N PARKSIDE AVE   486.0
# 3   9315087.0    HW459118  None          063XX S DAMEN AVE   820.0
# 4   9253603.0    HW398556  None             074XX S MAY ST  1310.0
# 5   9191663.0    HW336507  None           008XX N LONG AVE   560.0
# 6   9172834.0    HW317015  None       050XX W JACKSON BLVD  1320.0
# 7   9080818.0    HW207014  None           006XX W OHARE ST  2093.0
# 8   8784007.0    HV457778  None         061XX N KEDZIE AVE   460.0
# 9   8763217.0    HV438355  None            027XX W 84TH ST   820.0
# 10  8748933.0    HV423846  None         010XX N LEAVITT ST   820.0
# 11  8605751.0    HV279654  None       025XX S MICHIGAN AVE   266.0
# 12  8536104.0    HV212845  None        012XX N CENTRAL AVE   560.0
# 13  8245671.0    HT479249  None          018XX S MORGAN ST   486.0
# 14  7726097.0    HS533885  None         021XX W FOSTER AVE   486.0
# 15  7653198.0    HS452770  None          065XX S DAMEN AVE   486.0
# 16  7561932.0    HS350869  None     091XX S MARSHFIELD AVE  1821.0
# 17  7420003.0    HS222650  None  075XX S COTTAGE GROVE AVE  1811.0
# 18  7297647.0    HS101187  None            035XX W 78TH PL  2825.0
# 19  7236001.0    HR648721  None          044XX W THOMAS ST   486.0
# 20  7012516.0    HR419339  None       037XX W MARQUETTE RD   910.0
# 21  6932439.0    HR337650  None          007XX W TAYLOR ST  5000.0
# 22  6829260.0    HR237295  None          061XX S EVANS AVE   610.0
# 23  6752170.0    HR168666  None        037XX N KIMBALL AVE  1365.0
# 24  6486584.0    HP555914  None        056XX S WESTERN AVE  1320.0
# 25  6115508.0    HP210102  None        021XX W SCHILLER ST   610.0
# 26  6089645.0    HP188012  None           014XX N CLARK ST  1320.0
# 27  5568273.0    HN376006  None        061XX S KENNETH AVE  1310.0
# 28  5253960.0    HN130561  None        024XX N LINCOLN AVE  2825.0
# 29  5219015.0    HN102269  None            065XX W 63RD ST  1563.0
# ..        ...         ...   ...                        ...     ...
# 32  4916968.0    HM532103  None          011XX N MASON AVE  1330.0
# 33  4766250.0    HM368617  None         027XX N LEAVITT ST   486.0
# 34  4734877.0    HM338231  None          073XX S PERRY AVE   890.0
# 35  4818660.0    HM324419  None          062XX S HONORE ST  1811.0
# 36  4667546.0    HM256118  None      061XX S HERMITAGE AVE   460.0
# 37  4545395.0    HM133501  None         061XX N TALMAN AVE   610.0
# 38  4107490.0    HL447046  None       015XX W ROOSEVELT RD  1330.0
# 39  4105286.0    HL441159  None    048XX S ST LAWRENCE AVE  1320.0
# 40  4046540.0    HL397226  None          030XX S HOMAN AVE  1320.0
# 41  4046687.0    HL383729  None     073XX S MARSHFIELD AVE   460.0
# 42  3702239.0    HK806798  None        010XX W BELMONT AVE   820.0
# 43  3703743.0    HK719453  None       057XX N WINTHROP AVE  2027.0
# 44  3598082.0    HK690084  None         038XX N KEDZIE AVE   820.0
# 45  3229132.0    HK247310  None   043XX N NARRAGANSETT AVE   530.0
# 46  3168220.0    HK168668  None           018XX W HOOD AVE  1320.0
# 47  3072090.0    HJ784186  None         039XX W BELDEN AVE   560.0
# 48  3067419.0    HJ779424  None      003XX E GARFIELD BLVD  1330.0
# 49  3059683.0    HJ774309  None         028XX N WHIPPLE ST  1310.0
# 50  3040012.0    HJ753873  None          037XX W MYRICK ST  1365.0
# 51  3025055.0    HJ734174  None          053XX S MASON AVE   820.0
# 52  2942371.0    HJ630538  None          047XX N MARINE DR   810.0
# 53  2826786.0    HJ475063  None         033XX N AUSTIN AVE  2027.0
# 54  2597071.0    HJ194157  None       078XX S HAMILTON AVE   820.0
# 55  2237205.0    HH508647  None        085XX S SAGINAW AVE     NaN
# 56  2247497.0    HH507922  None         008XX S ALBANY AVE   430.0
# 57  1798858.0     G625214  None         006XX N MCCLURG CT   460.0
# 58  1680626.0     G472735  None       102XX S WENTWORTH AV   560.0
# 59  1352479.0     G049924  None           029XX S STATE ST  1350.0
# 60  1331785.0     G026414  None      066XX S WINCHESTER AV   460.0
# 61  1329175.0     G018301  None        057XX S MICHIGAN AV  1330.0
#
#            Primary Type               Location Description Arrest Domestic  \
# 0               ASSAULT                            CTA BUS  False    False
# 1               BATTERY     PARKING LOT/GARAGE(NON.RESID.)  False    False
# 2               BATTERY                           SIDEWALK  False     True
# 3                 THEFT                              OTHER  False    False
# 4       CRIMINAL DAMAGE                   RESIDENCE-GARAGE  False    False
# 5               ASSAULT                          APARTMENT  False     True
# 6       CRIMINAL DAMAGE                             STREET  False    False
# 7             NARCOTICS       GOVERNMENT BUILDING/PROPERTY   True    False
# 8               BATTERY                          APARTMENT   True    False
# 9                 THEFT             VEHICLE NON-COMMERCIAL   True    False
# 10                THEFT                             STREET  False    False
# 11  CRIM SEXUAL ASSAULT          HOSPITAL BUILDING/GROUNDS  False    False
# 12              ASSAULT                          RESIDENCE   True     True
# 13              BATTERY                          APARTMENT   True     True
# 14              BATTERY                          APARTMENT   True     True
# 15              BATTERY            RESIDENCE PORCH/HALLWAY  False     True
# 16            NARCOTICS                          RESIDENCE   True    False
# 17            NARCOTICS                             STREET   True    False
# 18        OTHER OFFENSE                          RESIDENCE  False    False
# 19              BATTERY                              OTHER   True     True
# 20  MOTOR VEHICLE THEFT                             STREET  False    False
# 21        OTHER OFFENSE                             STREET   True    False
# 22             BURGLARY                          APARTMENT  False    False
# 23    CRIMINAL TRESPASS                          RESIDENCE  False    False
# 24      CRIMINAL DAMAGE             VEHICLE NON-COMMERCIAL  False    False
# 25             BURGLARY            RESIDENCE PORCH/HALLWAY  False    False
# 26      CRIMINAL DAMAGE                             STREET  False    False
# 27      CRIMINAL DAMAGE  CHURCH/SYNAGOGUE/PLACE OF WORSHIP  False    False
# 28        OTHER OFFENSE                          RESIDENCE  False    False
# 29          SEX OFFENSE                          RESIDENCE  False    False
# ..                  ...                                ...    ...      ...
# 32    CRIMINAL TRESPASS                              OTHER   True    False
# 33              BATTERY                      CHA APARTMENT  False    False
# 34                THEFT                          RESIDENCE  False    False
# 35            NARCOTICS                             STREET   True    False
# 36              BATTERY                             STREET  False    False
# 37             BURGLARY                          RESIDENCE  False    False
# 38    CRIMINAL TRESPASS                        GAS STATION   True    False
# 39      CRIMINAL DAMAGE                              ALLEY  False    False
# 40      CRIMINAL DAMAGE                             STREET  False    False
# 41              BATTERY                          RESIDENCE  False    False
# 42                THEFT                           SIDEWALK  False    False
# 43            NARCOTICS                           SIDEWALK   True    False
# 44                THEFT                              OTHER   True    False
# 45              ASSAULT         COLLEGE/UNIVERSITY GROUNDS  False     True
# 46      CRIMINAL DAMAGE                             STREET  False    False
# 47              ASSAULT                           SIDEWALK  False     True
# 48    CRIMINAL TRESPASS                        GAS STATION   True    False
# 49      CRIMINAL DAMAGE                          RESIDENCE  False    False
# 50    CRIMINAL TRESPASS                   RESIDENCE-GARAGE  False    False
# 51                THEFT                             STREET  False    False
# 52                THEFT                             STREET  False    False
# 53            NARCOTICS                              OTHER   True    False
# 54                THEFT                             STREET  False    False
# 55              BATTERY                          RESIDENCE  False    False
# 56              BATTERY                             STREET  False    False
# 57              BATTERY                         DRUG STORE  False    False
# 58              ASSAULT                          RESIDENCE  False     True
# 59    CRIMINAL TRESPASS            CHA PARKING LOT/GROUNDS   True    False
# 60              BATTERY                           SIDEWALK  False    False
# 61    CRIMINAL TRESPASS           SCHOOL, PUBLIC, BUILDING  False    False
#
#       Beat  District  Ward  Community Area  FBI Code    Year   Latitude  \
# 0   1034.0      10.0  25.0            31.0       NaN  2014.0  41.851921
# 1   2234.0      22.0  34.0            75.0       NaN  2014.0  41.692230
# 2   1512.0      15.0  29.0            25.0       NaN  2013.0  41.882769
# 3    726.0       7.0  15.0            67.0       6.0  2013.0  41.779133
# 4    733.0       7.0  17.0            68.0      14.0  2013.0  41.759419
# 5   1524.0      15.0  37.0            25.0       NaN  2013.0  41.895892
# 6   1533.0      15.0  28.0            25.0      14.0  2013.0  41.876798
# 7   1654.0      16.0  41.0            76.0      26.0  2013.0  41.953791
# 8   2413.0      24.0  50.0             2.0       NaN  2012.0  41.993487
# 9    835.0       8.0  18.0            70.0       6.0  2012.0  41.740815
# 10  1312.0      12.0  32.0            24.0       6.0  2012.0  41.899614
# 11   133.0       1.0   2.0            33.0       2.0  2012.0  41.846716
# 12  2531.0      25.0  29.0            25.0       NaN  2012.0  41.902884
# 13  1233.0      12.0  25.0            31.0       NaN  2011.0  41.856731
# 14  2012.0      20.0  40.0             4.0       NaN  2010.0  41.976100
# 15   726.0       7.0  15.0            67.0       NaN  2010.0  41.774075
# 16  2221.0      22.0  21.0            73.0      18.0  2010.0  41.727458
# 17   624.0       6.0   6.0            69.0      18.0  2010.0  41.758395
# 18   835.0       8.0  18.0            70.0      26.0  2010.0  41.750699
# 19  1111.0      11.0  37.0            23.0       NaN  2009.0  41.900763
# 20   833.0       8.0  13.0            65.0       7.0  2009.0  41.771571
# 21   131.0       1.0   2.0            28.0      26.0  2009.0  41.869585
# 22   313.0       3.0  20.0            42.0       5.0  2009.0  41.782393
# 23  1733.0      17.0  35.0            16.0      26.0  2009.0  41.949571
# 24   824.0       8.0  16.0            63.0      14.0  2008.0  41.791446
# 25  1424.0      14.0  32.0            24.0       5.0  2008.0  41.907174
# 26  1821.0      18.0  42.0             8.0      14.0  2008.0  41.907956
# 27   813.0       8.0  13.0            65.0      14.0  2007.0  41.780788
# 28  1933.0      19.0  43.0             7.0      26.0  2007.0  41.926056
# 29   812.0       8.0  23.0            64.0      17.0  2007.0  41.777522
# ..     ...       ...   ...             ...       ...     ...        ...
# 32  1511.0      15.0  29.0            25.0      26.0  2006.0  41.900578
# 33  1913.0      19.0   1.0             7.0       NaN  2006.0  41.931910
# 34   731.0       7.0   6.0            69.0       6.0  2006.0  41.760285
# 35   714.0       7.0  15.0            67.0      18.0  2006.0  41.780466
# 36   714.0       7.0  15.0            67.0       NaN  2006.0  41.782362
# 37  2413.0      24.0  50.0             2.0       5.0  2006.0  41.993644
# 38  1231.0      12.0   2.0            28.0      26.0  2005.0  41.866751
# 39   223.0       2.0   4.0            38.0      14.0  2005.0  41.806206
# 40  1032.0      10.0  22.0            30.0      14.0  2005.0  41.838789
# 41   735.0       7.0  17.0            67.0       NaN  2005.0  41.759821
# 42  1924.0      19.0  44.0             6.0       6.0  2004.0  41.940019
# 43  2022.0      20.0  48.0            77.0      18.0  2004.0  41.985801
# 44  1733.0      17.0  33.0            16.0       6.0  2004.0  41.951223
# 45  1632.0      16.0  38.0            17.0       NaN  2004.0  41.958461
# 46  2413.0      24.0  40.0             2.0      14.0  2004.0  41.993257
# 47  2525.0      25.0  30.0            22.0       NaN  2003.0  41.922571
# 48   234.0       2.0   3.0            40.0      26.0  2003.0  41.794908
# 49  1411.0      14.0  35.0            21.0      14.0  2003.0  41.932869
# 50   833.0       8.0  18.0            70.0      26.0  2003.0  41.750112
# 51   811.0       8.0  23.0            56.0       6.0  2003.0  41.794915
# 52  2312.0      19.0  46.0             3.0       6.0  2003.0  41.968299
# 53  1633.0      16.0  38.0            15.0      18.0  2003.0  41.941972
# 54   611.0       NaN  18.0            71.0       6.0  2003.0  41.751476
# 55   423.0       NaN   7.0            46.0       NaN  2002.0  41.739520
# 56  1134.0       NaN  24.0            27.0       NaN  2002.0  41.870932
# 57  1834.0       NaN   NaN             NaN       NaN  2001.0  41.894712
# 58   511.0       NaN   NaN             NaN       NaN  2001.0  41.708727
# 59  2113.0       NaN   NaN             NaN      26.0  2001.0  41.840053
# 60   726.0       NaN   NaN             NaN       NaN  2001.0  41.773816
# 61   233.0       NaN   NaN             NaN      26.0  2001.0  41.789841
#
#     Longitude
# 0  -87.685861
# 1  -87.661557
# 2  -87.766450
# 3  -87.674052
# 4  -87.652607
# 5  -87.760820
# 6  -87.752667
# 7  -87.907473
# 8  -87.709079
# 9  -87.690676
# 10 -87.682199
# 11 -87.623370
# 12 -87.765827
# 13 -87.651682
# 14 -87.682432
# 15 -87.673616
# 16 -87.664187
# 17 -87.605531
# 18 -87.710495
# 19 -87.738109
# 20 -87.716826
# 21 -87.643806
# 22 -87.607086
# 23 -87.712651
# 24 -87.684123
# 25 -87.681545
# 26 -87.631722
# 27 -87.733665
# 28 -87.649835
# 29 -87.784110
# ..        ...
# 32 -87.773958
# 33 -87.680489
# 34 -87.627905
# 35 -87.670151
# 36 -87.667782
# 37 -87.695706
# 38 -87.665820
# 39 -87.611233
# 40 -87.709608
# 41 -87.665050
# 42 -87.654118
# 43 -87.658233
# 44 -87.708091
# 45 -87.786920
# 46 -87.676205
# 47 -87.724366
# 48 -87.616450
# 49 -87.703922
# 50 -87.716599
# 51 -87.771064
# 52 -87.649545
# 53 -87.776206
# 54 -87.676966
# 55 -87.559823
# 56 -87.703521
# 57 -87.617928
# 58 -87.628212
# 59 -87.626978
# 60 -87.672409
# 61 -87.622491
#
# [62 rows x 17 columns]
