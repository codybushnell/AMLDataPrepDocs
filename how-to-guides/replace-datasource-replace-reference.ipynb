# %% [markdown]
# # Replace DataSource Reference
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# A common practice when performing DataPrep is to build up a script or set of cleaning operations on a smaller example file locally. This is quicker and easier than dealing with large amounts of data initially.
#
# After building a Dataflow that performs the desired steps, it's time to run it against the larger dataset, which may be stored in the cloud, or even locally just in a different file. This is where we can use `Dataflow.replace_datasource` to get a Dataflow identical to the one built on the small data, but referencing the newly specified DataSource.

# %%
import azureml.dataprep as dprep

dflow = dprep.read_csv('../data/crime-spring.csv')
df = dflow.to_pandas_dataframe()
df
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
# 5  10535059    HZ278872   4/15/2016 4:30    004XX S KILBOURN AVE   810
# 6  10499802    HZ240778  4/15/2016 10:00   010XX N MILWAUKEE AVE  1152
# 7  10522293    HZ264802  4/15/2016 16:00     019XX W DIVISION ST  1110
# 8  10523111    HZ265911   4/15/2016 8:00     061XX N SHERIDAN RD  1153
# 9  10525877    HZ268138  4/15/2016 15:00    023XX W EASTWOOD AVE  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
# 5               THEFT                                OVER $500
# 6  DECEPTIVE PRACTICE                    ILLEGAL USE CASH CARD
# 7  DECEPTIVE PRACTICE                              BOGUS CHECK
# 8  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 9  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
# 5                 RESIDENCE  FALSE    FALSE              ...
# 6                 RESIDENCE  FALSE    FALSE              ...
# 7                RESTAURANT  FALSE    FALSE              ...
# 8                 RESIDENCE  FALSE    FALSE              ...
# 9                            FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
# 5   24             26        6                            2016
# 6   27             24       11                            2016
# 7    1             24       11      1163094      1908003  2016
# 8   48             77       11                            2016
# 9   47              4       11                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
# 5  5/25/2016 15:59
# 6  5/27/2016 15:45
# 7  5/16/2016 15:48  41.90320604  -87.67636193  (41.903206037, -87.676361925)
# 8  5/16/2016 15:50
# 9  5/18/2016 15:50
#
# [10 rows x 22 columns]

# %% [markdown]
# Here we have the first 10 rows of a dataset called 'Crime'. The original dataset is over 100MB (admittedly not that large of a dataset but this is just an example).
#
# We'll perform a few cleaning operations.

# %%
dflow_dropped = dflow.drop_columns(['Location', 'Updated On', 'X Coordinate', 'Y Coordinate', 'Description'])
sctb = dflow_dropped.builders.set_column_types()
sctb.learn(inference_arguments=dprep.InferenceArguments(day_first=False))
dflow_typed = sctb.to_dataflow()
dflow_typed.head(5)
# Out:
#            ID Case Number                Date                   Block    IUCR  \
# 0  10498554.0    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598.0    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196.0    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591.0    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446.0    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#          Primary Type      Location Description Arrest Domestic    Beat  \
# 0  DECEPTIVE PRACTICE                     OTHER  False    False   531.0
# 1               THEFT                 RESIDENCE  False    False   614.0
# 2  DECEPTIVE PRACTICE                 RESIDENCE  False    False  2211.0
# 3  DECEPTIVE PRACTICE                 RESIDENCE  False    False   531.0
# 4               THEFT  SCHOOL, PUBLIC, BUILDING  False    False  1712.0
#
#    District  Ward  Community Area  FBI Code    Year   Latitude  Longitude
# 0       5.0   9.0            50.0      11.0  2016.0  41.692834 -87.604319
# 1       6.0  21.0            71.0       6.0  2016.0  41.744107 -87.664494
# 2      22.0  19.0            74.0      11.0  2016.0        NaN        NaN
# 3       5.0   9.0            49.0      10.0  2016.0        NaN        NaN
# 4      17.0  40.0            13.0       6.0  2016.0        NaN        NaN

# %% [markdown]
# Now that we have a Dataflow with all our desired steps, we're ready to run against the 'full' dataset stored in Azure Blob.
# All we need to do is pass the BlobDataSource into `replace_datasource` and we'll get back an identical Dataflow with the new DataSource substituted in.

# %%
dflow_replaced = dflow_typed.replace_datasource(dprep.BlobDataSource('https://dpreptestfiles.blob.core.windows.net/testfiles/crime0.csv'))

# %% [markdown]
# 'replaced_dflow' will now pull data from the 168MB (729734 rows) version of Crime0.csv stored in Azure Blob!
#
# NOTE: Dataflows can also be created by referencing a different Dataflow. Instead of using `replace_datasource`, there is a corresponding `replace_reference` method.
#
# We should be careful now since pulling all that data down and putting it in a pandas dataframe isn't an ideal way to inspect the result of our Dataflow. So instead, to see that our steps are being applied to all the new data, we can add a `take_sample` step, which will select records at random (based on a given probability) to be returned.
#
# The probability below takes the ~730000 rows down to a more inspectable ~73, though the number will vary each time `to_pandas_dataframe()` is run, since they are being randomly selected based on the probability.

# %%
dflow_random_sample= dflow_replaced.take_sample(probability=0.0001)
sample = dflow_random_sample.to_pandas_dataframe()
sample
# Out:
#             ID Case Number  Date                     Block    IUCR  \
# 0   10057582.0    HY246601  None      088XX S CARPENTER ST   810.0
# 1    9934003.0    HY122673  None      065XX N BOSWORTH AVE     NaN
# 2    9725690.0    HX375502  None          059XX N CLARK ST  1310.0
# 3    9654432.0    HX305212  None          0000X W 114TH ST  1310.0
# 4    9502156.0    HX156837  None         095XX S PERRY AVE   810.0
# 5    9464773.0    HX117414  None         021XX N TRIPP AVE  4387.0
# 6    9450414.0    HX103495  None      040XX N PARKSIDE AVE   910.0
# 7    9422254.0    HW565794  None       029XX N LINCOLN AVE   810.0
# 8    9418186.0    HW561156  None       046XX S CALUMET AVE  1310.0
# 9    9356240.0    HW499906  None       028XX W CHICAGO AVE   820.0
# 10   9324261.0    HW467802  None          017XX W LUNT AVE   890.0
# 11   9204732.0    HW349001  None      060XX W WAVELAND AVE   486.0
# 12   9150553.0    HW296319  None     079XX S LAFAYETTE AVE   460.0
# 13   9059309.0    HW204003  None       064XX S LANGLEY AVE   810.0
# 14   8993834.0    HW140700  None         036XX S HOYNE AVE   337.0
# 15   8984716.0    HW132066  None          046XX N CLARK ST   910.0
# 16   8982800.0    HW130072  None      035XX W DOUGLAS BLVD  2825.0
# 17   8780793.0    HV453823  None       003XX S KOSTNER AVE   486.0
# 18   8577967.0    HV252457  None           015XX W 80TH ST  1811.0
# 19   8357830.0    HT591332  None      033XX W LAWRENCE AVE   320.0
# 20   8241423.0    HT475069  None           020XX W 35TH ST   810.0
# 21   8180828.0    HT414147  None         075XX S UNION AVE   560.0
# 22   8178224.0    HT413201  None     005XX N DESPLAINES ST   460.0
# 23   7963364.0    HT195348  None  015XX S CENTRAL PARK AVE   560.0
# 24   7871512.0    HS678604  None        022XX N SAWYER AVE   910.0
# 25   7777985.0    HS586178  None           017XX E 68TH ST  2027.0
# 26   7739179.0    HS539434  None      089XX S ESCANABA AVE  1310.0
# 27   7695788.0    HS484158  None         038XX W NORTH AVE  1506.0
# 28   7669137.0    HS474074  None     030XX W BRYN MAWR AVE  1305.0
# 29   7618952.0    HS419487  None     069XX S CLAREMONT AVE   460.0
# ..         ...         ...   ...                       ...     ...
# 62   3880968.0    HL228154  None      032XX W DOUGLAS BLVD  2095.0
# 63   3661125.0    HK759370  None        057XX S CICERO AVE   820.0
# 64   3651931.0    HK742810  None       100XX S LA SALLE ST   460.0
# 65   3620743.0    HK714264  None   026XX S CALIFORNIA BLVD   810.0
# 66   3579476.0    HK633188  None         024XX N LAMON AVE  2022.0
# 67   3519733.0    HK597627  None        051XX W PARKER AVE   820.0
# 68   3469032.0    HK540098  None       073XX S WESTERN AVE  1320.0
# 69   3385061.0    HK437537  None         046XX W DEMING PL  4387.0
# 70   3324899.0    HK362629  None           026XX E 79TH ST   460.0
# 71   3960539.0    HL323932  None        049XX W MADISON ST   486.0
# 72   3293023.0    HK288811  None          119XX S STATE ST  1506.0
# 73   2976735.0    HJ672869  None           015XX E 83RD PL     NaN
# 74   2947933.0    HJ637034  None     025XX N MILWAUKEE AVE  2017.0
# 75   2738956.0    HJ373816  None      026XX W FARRAGUT AVE   486.0
# 76   2713588.0    HJ301182  None         024XX N MAJOR AVE  1811.0
# 77   2393411.0    HH703997  None      086XX S ESCANABA AVE   337.0
# 78   2314957.0    HH601467  None     017XX W FULLERTON AVE   890.0
# 79   2356809.0    HH632230  None        065XX S PULASKI RD  1150.0
# 80   2204506.0    HH461706  None     059XX S EGGLESTON AVE     NaN
# 81   2164128.0    HH405774  None         003XX S LOTUS AVE  1811.0
# 82   2146145.0    HH390051  None     075XX N CLAREMONT AVE   610.0
# 83   1949290.0    HH137622  None     042XX S CALIFORNIA AV   460.0
# 84   1935772.0    HH118013  None          013XX W CHASE AV  1310.0
# 85   1792062.0     G614620  None     010XX N CALIFORNIA AV     NaN
# 86   1745076.0     G548286  None       039XX W DIVISION ST   820.0
# 87   1702657.0     G499088  None         109XX S VERNON AV   530.0
# 88   1677068.0     G456197  None      044XX W LEXINGTON ST  2024.0
# 89   1593818.0     G361294  None     064XX S MARSHFIELD AV   610.0
# 90   1446237.0     G173411  None          062XX W TOUHY AV   610.0
# 91   1400156.0     G115613  None        009XX W NEWPORT AV   820.0
#
#            Primary Type               Location Description Arrest Domestic  \
# 0                 THEFT                          RESIDENCE  False    False
# 1               ROBBERY                              ALLEY  False    False
# 2       CRIMINAL DAMAGE                 SMALL RETAIL STORE  False    False
# 3       CRIMINAL DAMAGE            RESIDENCE PORCH/HALLWAY  False     True
# 4                 THEFT                          APARTMENT  False    False
# 5         OTHER OFFENSE                          APARTMENT   True     True
# 6   MOTOR VEHICLE THEFT                             STREET  False    False
# 7                 THEFT                             STREET  False    False
# 8       CRIMINAL DAMAGE                          APARTMENT  False    False
# 9                 THEFT                             STREET  False    False
# 10                THEFT  CHURCH/SYNAGOGUE/PLACE OF WORSHIP  False    False
# 11              BATTERY                          RESIDENCE  False    False
# 12              BATTERY                           SIDEWALK  False    False
# 13                THEFT                          APARTMENT  False     True
# 14              ROBBERY                           SIDEWALK   True    False
# 15  MOTOR VEHICLE THEFT                             STREET  False    False
# 16        OTHER OFFENSE                          RESIDENCE  False    False
# 17              BATTERY                          APARTMENT  False    False
# 18            NARCOTICS                           SIDEWALK   True    False
# 19              ROBBERY                          CTA TRAIN   True    False
# 20                THEFT      RESIDENTIAL YARD (FRONT/BACK)  False    False
# 21              ASSAULT                          APARTMENT  False    False
# 22              BATTERY                              OTHER  False    False
# 23              ASSAULT                          APARTMENT  False    False
# 24  MOTOR VEHICLE THEFT                             STREET  False    False
# 25            NARCOTICS            RESIDENCE PORCH/HALLWAY   True    False
# 26      CRIMINAL DAMAGE                          RESIDENCE  False    False
# 27         PROSTITUTION                             STREET   True    False
# 28      CRIMINAL DAMAGE                      PARK PROPERTY  False    False
# 29              BATTERY      RESIDENTIAL YARD (FRONT/BACK)  False    False
# ..                  ...                                ...    ...      ...
# 62            NARCOTICS                           SIDEWALK   True    False
# 63                THEFT     PARKING LOT/GARAGE(NON.RESID.)  False    False
# 64              BATTERY                              ALLEY   True    False
# 65                THEFT                             STREET  False    False
# 66            NARCOTICS                             STREET   True    False
# 67                THEFT                          RESIDENCE  False    False
# 68      CRIMINAL DAMAGE                             STREET  False    False
# 69        OTHER OFFENSE                          RESIDENCE   True     True
# 70              BATTERY                             STREET  False    False
# 71              BATTERY                             STREET  False    False
# 72         PROSTITUTION                             STREET   True    False
# 73              ROBBERY                             STREET  False    False
# 74            NARCOTICS                           SIDEWALK   True    False
# 75              BATTERY                          RESIDENCE  False    False
# 76            NARCOTICS             VEHICLE NON-COMMERCIAL   True    False
# 77              ROBBERY                             STREET  False    False
# 78                THEFT                   DEPARTMENT STORE  False    False
# 79   DECEPTIVE PRACTICE                               BANK   True    False
# 80              ASSAULT                             STREET  False    False
# 81            NARCOTICS                             STREET   True    False
# 82             BURGLARY                          RESIDENCE  False    False
# 83              BATTERY                          RESIDENCE  False    False
# 84      CRIMINAL DAMAGE                              OTHER  False     True
# 85              ASSAULT                      BAR OR TAVERN  False    False
# 86                THEFT                        GAS STATION   True    False
# 87              ASSAULT                           SIDEWALK   True    False
# 88            NARCOTICS                             STREET   True    False
# 89             BURGLARY                          RESIDENCE  False    False
# 90             BURGLARY                 SMALL RETAIL STORE  False    False
# 91                THEFT                          RESIDENCE  False    False
#
#       Beat  District  Ward  Community Area  FBI Code    Year   Latitude  \
# 0   2222.0      22.0  21.0            71.0       6.0  2015.0  41.733282
# 1   2432.0      24.0  40.0             1.0       3.0  2015.0  42.000257
# 2   2013.0      20.0  48.0            77.0      14.0  2014.0  41.989122
# 3    522.0       5.0  34.0            49.0      14.0  2014.0  41.687014
# 4    511.0       5.0  21.0            49.0       6.0  2014.0  41.720154
# 5   2522.0      25.0  30.0            20.0      26.0  2014.0  41.919658
# 6   1624.0      16.0  38.0            15.0       7.0  2014.0  41.953347
# 7   1933.0      19.0  32.0             6.0       6.0  2013.0  41.935904
# 8    215.0       2.0   3.0            38.0      14.0  2013.0  41.810340
# 9   1211.0      12.0  26.0            24.0       6.0  2013.0  41.895763
# 10  2423.0      24.0  49.0             1.0       6.0  2013.0  42.009113
# 11  1633.0      16.0  38.0            17.0       NaN  2013.0  41.947474
# 12   623.0       6.0  17.0            44.0       NaN  2013.0  41.750863
# 13   312.0       3.0  20.0            42.0       6.0  2013.0  41.777717
# 14   912.0       9.0  11.0            59.0       3.0  2013.0  41.826896
# 15  1912.0      19.0  47.0             3.0       7.0  2013.0  41.965434
# 16  1021.0      10.0  24.0            29.0      26.0  2013.0  41.862294
# 17  1131.0      11.0  28.0            26.0       NaN  2012.0  41.876310
# 18   612.0       6.0  21.0            71.0      18.0  2012.0  41.748660
# 19  1713.0      17.0  33.0            14.0       3.0  2011.0  41.968292
# 20   913.0       9.0  11.0            59.0       6.0  2011.0  41.830262
# 21   621.0       6.0  17.0            68.0       NaN  2011.0  41.757632
# 22  1323.0      12.0  27.0            24.0       NaN  2011.0  41.891499
# 23  1014.0      10.0  24.0            29.0       NaN  2011.0  41.860464
# 24  1413.0      14.0  26.0            22.0       7.0  2010.0  41.922478
# 25   332.0       3.0   5.0            43.0      18.0  2010.0  41.771414
# 26   423.0       4.0  10.0            46.0      14.0  2010.0  41.732861
# 27  2535.0      25.0  30.0            23.0      16.0  2010.0  41.909823
# 28  2011.0      20.0  40.0             2.0      14.0  2010.0  41.983200
# 29   832.0       8.0  17.0            66.0       NaN  2010.0  41.767414
# ..     ...       ...   ...             ...       ...     ...        ...
# 62  1022.0      10.0  24.0            29.0      18.0  2005.0  41.862387
# 63   813.0       8.0  23.0            56.0       6.0  2004.0  41.789467
# 64   511.0       5.0   9.0            49.0       NaN  2004.0  41.711192
# 65  1034.0      10.0  12.0            30.0       6.0  2004.0  41.844687
# 66  2521.0      25.0  31.0            19.0      18.0  2004.0  41.924597
# 67  2521.0      25.0  31.0            19.0       6.0  2004.0  41.930633
# 68   835.0       8.0  18.0            66.0      14.0  2004.0  41.759433
# 69  2521.0      25.0  31.0            19.0      26.0  2004.0  41.927366
# 70   422.0       4.0   7.0            46.0       NaN  2004.0  41.751711
# 71  1533.0      15.0  28.0            25.0       NaN  2004.0  41.880570
# 72   522.0       5.0   9.0            53.0      16.0  2004.0  41.678012
# 73   412.0       4.0   8.0            45.0       3.0  2003.0  41.743385
# 74  1414.0      14.0  35.0            22.0      18.0  2003.0  41.927821
# 75  2011.0       NaN  40.0             4.0       NaN  2003.0  41.976650
# 76  2515.0       NaN  30.0            19.0      18.0  2003.0  41.923950
# 77   423.0       NaN  10.0            46.0       3.0  2002.0  41.737439
# 78  1931.0       NaN  32.0             7.0       6.0  2002.0  41.925211
# 79   833.0       NaN  13.0            65.0      11.0  2002.0  41.774966
# 80   711.0       NaN  20.0            68.0       NaN  2002.0  41.786459
# 81  1522.0       NaN  29.0            25.0      18.0  2002.0  41.876182
# 82  2411.0       NaN  49.0             2.0       5.0  2002.0  42.018200
# 83   912.0       NaN   NaN             NaN       NaN  2002.0  41.815913
# 84  2423.0       NaN   NaN             NaN      14.0  2002.0  42.014025
# 85  1311.0       NaN   NaN             NaN       NaN  2001.0  41.899381
# 86  2535.0       NaN   NaN             NaN       6.0  2001.0  41.902785
# 87   513.0       NaN   NaN             NaN       NaN  2001.0  41.695224
# 88  1131.0       NaN   NaN             NaN      18.0  2001.0  41.871641
# 89   725.0       NaN   NaN             NaN       5.0  2001.0  41.776755
# 90  1621.0       NaN   NaN             NaN       5.0  2001.0  42.011893
# 91  2331.0       NaN   NaN             NaN       6.0  2001.0  41.944366
#
#     Longitude
# 0  -87.649776
# 1  -87.669085
# 2  -87.669785
# 3  -87.624126
# 4  -87.626351
# 5  -87.732609
# 6  -87.768380
# 7  -87.663181
# 8  -87.618325
# 9  -87.697183
# 10 -87.672996
# 11 -87.777287
# 12 -87.625967
# 13 -87.608473
# 14 -87.677774
# 15 -87.666917
# 16 -87.714773
# 17 -87.735178
# 18 -87.662241
# 19 -87.713094
# 20 -87.676925
# 21 -87.641927
# 22 -87.644522
# 23 -87.715400
# 24 -87.709235
# 25 -87.582077
# 26 -87.553942
# 27 -87.721772
# 28 -87.705292
# 29 -87.682152
# ..        ...
# 62 -87.706652
# 63 -87.741413
# 64 -87.627361
# 65 -87.694808
# 66 -87.748937
# 67 -87.754126
# 68 -87.682965
# 69 -87.743595
# 70 -87.559570
# 71 -87.748035
# 72 -87.622808
# 73 -87.586537
# 74 -87.705600
# 75 -87.695007
# 76 -87.768275
# 77 -87.554019
# 78 -87.671929
# 79 -87.722520
# 80 -87.636290
# 81 -87.761822
# 82 -87.689116
# 83 -87.694588
# 84 -87.665821
# 85 -87.696942
# 86 -87.726064
# 87 -87.612081
# 88 -87.736577
# 89 -87.665270
# 90 -87.783431
# 91 -87.652723
#
# [92 rows x 17 columns]
