# %% [markdown]
# # Replace, Fill, Error
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# You can use the methods in this notebook to change values in your dataset.
#
# * <a href='#replace'>replace</a> - use this method to replace a value with another value. You can also use this to replace null with a value, or a value with null
# * <a href='#error'>error</a> - use this method to replace a value with an error.
# * <a href='#fill_nulls'>fill_nulls</a> - this method lets you fill all nulls in a column with a certain value.
# * <a href='#fill_errors'>fill_errors</a> - this method lets you fill all errors in a column with a certain value.

# %% [markdown]
# ## Setup

# %%
import azureml.dataprep as dprep

# %%
dflow = dprep.read_csv('../data/crime-spring.csv')
dflow.head(5)
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %%
dflow = dflow.to_datetime('Date', ['%m/%d/%Y %H:%M'])
dflow = dflow.to_number(['IUCR', 'District', 'FBI Code'])
dflow.head(5)
# Out:
#          ID Case Number                Date                   Block    IUCR  \
# 0  10498554    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward  Community Area FBI Code X Coordinate  Y Coordinate  Year  \
# 0    9              50     11.0      1183356       1831503  2016
# 1   21              71      6.0      1166776       1850053  2016
# 2   19              74     11.0                             2016
# 3    9              49     10.0                             2016
# 4   40              13      6.0                             2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Replace <a id='replace'></a>

# %% [markdown]
# ### String
# Use `replace` to swap a string value with another string value.

# %%
dflow = dflow.replace('Primary Type', 'THEFT', 'STOLEN')
head = dflow.head(5)
head
# Out:
#          ID Case Number                Date                   Block    IUCR  \
# 0  10498554    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1              STOLEN                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4              STOLEN                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward  Community Area FBI Code X Coordinate  Y Coordinate  Year  \
# 0    9              50     11.0      1183356       1831503  2016
# 1   21              71      6.0      1166776       1850053  2016
# 2   19              74     11.0                             2016
# 3    9              49     10.0                             2016
# 4   40              13      6.0                             2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# Use `replace` to remove a certain string value from the column, replacing it with null. Note that Pandas shows null values as None.

# %%
dflow = dflow.replace('Primary Type', 'DECEPTIVE PRACTICE', None)
head = dflow.head(5)
head
# Out:
#          ID Case Number                Date                   Block    IUCR  \
# 0  10498554    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#   Primary Type                              Description  \
# 0         None      FINANCIAL IDENTITY THEFT OVER $ 300
# 1       STOLEN                            FROM BUILDING
# 2         None  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3         None                                  FORGERY
# 4       STOLEN                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward  Community Area FBI Code X Coordinate  Y Coordinate  Year  \
# 0    9              50     11.0      1183356       1831503  2016
# 1   21              71      6.0      1166776       1850053  2016
# 2   19              74     11.0                             2016
# 3    9              49     10.0                             2016
# 4   40              13      6.0                             2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Numeric
# Use `replace` to swap a numeric value with another numeric value.

# %%
dflow = dflow.replace('District', 5, 1)
head = dflow.head(5)
head
# Out:
#          ID Case Number                Date                   Block    IUCR  \
# 0  10498554    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#   Primary Type                              Description  \
# 0         None      FINANCIAL IDENTITY THEFT OVER $ 300
# 1       STOLEN                            FROM BUILDING
# 2         None  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3         None                                  FORGERY
# 4       STOLEN                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward  Community Area FBI Code X Coordinate  Y Coordinate  Year  \
# 0    9              50     11.0      1183356       1831503  2016
# 1   21              71      6.0      1166776       1850053  2016
# 2   19              74     11.0                             2016
# 3    9              49     10.0                             2016
# 4   40              13      6.0                             2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Date
# Use `replace` to swap in a new Date for an existing Date in the data.

# %%
from datetime import datetime, timezone
dflow = dflow.replace('Date', 
                 datetime(2016, 4, 15, 9, 0, tzinfo=timezone.utc), 
                 datetime(2018, 7, 4, 0, 0, tzinfo=timezone.utc))
head = dflow.head(5)
head
# Out:
#          ID Case Number                Date                   Block    IUCR  \
# 0  10498554    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591    HZ261534 2018-07-04 00:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#   Primary Type                              Description  \
# 0         None      FINANCIAL IDENTITY THEFT OVER $ 300
# 1       STOLEN                            FROM BUILDING
# 2         None  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3         None                                  FORGERY
# 4       STOLEN                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward  Community Area FBI Code X Coordinate  Y Coordinate  Year  \
# 0    9              50     11.0      1183356       1831503  2016
# 1   21              71      6.0      1166776       1850053  2016
# 2   19              74     11.0                             2016
# 3    9              49     10.0                             2016
# 4   40              13      6.0                             2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Error <a id='error'></a>
#
# The `error` method lets you create Error values. You can pass to this function the value that you want to find, along with the Error code to use in any Errors created.

# %%
dflow = dflow.error('IUCR', 890, 'Invalid value')
head = dflow.head(5)
head
# Out:
#          ID Case Number                Date                   Block  \
# 0  10498554    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST
# 1  10516598    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE
# 2  10519196    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE
# 3  10519591    HZ261534 2018-07-04 00:00:00     113XX S PRAIRIE AVE
# 4  10534446    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE
#
#                                                 IUCR Primary Type  \
# 0                                               1153         None
# 1  azureml.dataprep.native.DataPrepError("'Invali...       STOLEN
# 2                                               1154         None
# 3                                               1120         None
# 4  azureml.dataprep.native.DataPrepError("'Invali...       STOLEN
#
#                                Description      Location Description Arrest  \
# 0      FINANCIAL IDENTITY THEFT OVER $ 300                     OTHER  FALSE
# 1                            FROM BUILDING                 RESIDENCE  FALSE
# 2  FINANCIAL IDENTITY THEFT $300 AND UNDER                 RESIDENCE  FALSE
# 3                                  FORGERY                 RESIDENCE  FALSE
# 4                            FROM BUILDING  SCHOOL, PUBLIC, BUILDING  FALSE
#
#   Domestic              ...               Ward  Community Area FBI Code  \
# 0    FALSE              ...                  9              50     11.0
# 1    FALSE              ...                 21              71      6.0
# 2    FALSE              ...                 19              74     11.0
# 3    FALSE              ...                  9              49     10.0
# 4    FALSE              ...                 40              13      6.0
#
#   X Coordinate  Y Coordinate  Year       Updated On     Latitude  \
# 0      1183356       1831503  2016  5/11/2016 15:48  41.69283384
# 1      1166776       1850053  2016  5/12/2016 15:48  41.74410697
# 2                             2016  5/12/2016 15:50
# 3                             2016  5/13/2016 15:51
# 4                             2016  5/25/2016 15:59
#
#       Longitude                       Location
# 0  -87.60431945   (41.692833841, -87.60431945)
# 1  -87.66449429  (41.744106973, -87.664494285)
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Fill Nulls <a id='fill_nulls'></a>
#
# Use the `fill_nulls` method to replace all null values in columns with another value. This is similar to Panda's fillna() method.

# %%
dflow = dflow.fill_nulls('Primary Type', 'N/A')
head = dflow.head(5)
head
# Out:
#          ID Case Number                Date                   Block  \
# 0  10498554    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST
# 1  10516598    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE
# 2  10519196    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE
# 3  10519591    HZ261534 2018-07-04 00:00:00     113XX S PRAIRIE AVE
# 4  10534446    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE
#
#                                                 IUCR Primary Type  \
# 0                                               1153          N/A
# 1  azureml.dataprep.native.DataPrepError("'Invali...       STOLEN
# 2                                               1154          N/A
# 3                                               1120          N/A
# 4  azureml.dataprep.native.DataPrepError("'Invali...       STOLEN
#
#                                Description      Location Description Arrest  \
# 0      FINANCIAL IDENTITY THEFT OVER $ 300                     OTHER  FALSE
# 1                            FROM BUILDING                 RESIDENCE  FALSE
# 2  FINANCIAL IDENTITY THEFT $300 AND UNDER                 RESIDENCE  FALSE
# 3                                  FORGERY                 RESIDENCE  FALSE
# 4                            FROM BUILDING  SCHOOL, PUBLIC, BUILDING  FALSE
#
#   Domestic              ...               Ward  Community Area FBI Code  \
# 0    FALSE              ...                  9              50     11.0
# 1    FALSE              ...                 21              71      6.0
# 2    FALSE              ...                 19              74     11.0
# 3    FALSE              ...                  9              49     10.0
# 4    FALSE              ...                 40              13      6.0
#
#   X Coordinate  Y Coordinate  Year       Updated On     Latitude  \
# 0      1183356       1831503  2016  5/11/2016 15:48  41.69283384
# 1      1166776       1850053  2016  5/12/2016 15:48  41.74410697
# 2                             2016  5/12/2016 15:50
# 3                             2016  5/13/2016 15:51
# 4                             2016  5/25/2016 15:59
#
#       Longitude                       Location
# 0  -87.60431945   (41.692833841, -87.60431945)
# 1  -87.66449429  (41.744106973, -87.664494285)
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Fill Errors <a id='fill_errors'></a>
#
# Use the `fill_errors` method to replace all error values in columns with another value.

# %%
dflow = dflow.fill_errors('IUCR', -1)
head = dflow.head(5)
head
# Out:
#          ID Case Number                Date                   Block    IUCR  \
# 0  10498554    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE    -1.0
# 2  10519196    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591    HZ261534 2018-07-04 00:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE    -1.0
#
#   Primary Type                              Description  \
# 0          N/A      FINANCIAL IDENTITY THEFT OVER $ 300
# 1       STOLEN                            FROM BUILDING
# 2          N/A  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3          N/A                                  FORGERY
# 4       STOLEN                            FROM BUILDING
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
#
#   Ward  Community Area FBI Code X Coordinate  Y Coordinate  Year  \
# 0    9              50     11.0      1183356       1831503  2016
# 1   21              71      6.0      1166776       1850053  2016
# 2   19              74     11.0                             2016
# 3    9              49     10.0                             2016
# 4   40              13      6.0                             2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
#
# [5 rows x 22 columns]
