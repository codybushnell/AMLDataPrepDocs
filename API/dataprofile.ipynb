# %% [markdown]
# # Data Profile
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# A DataProfile collects summary statistics on the data produced by a Dataflow. `Dataflow.get_profile()` executes the Dataflow and returns a newly constructed DataProfile.

# %%
import azureml.dataprep as dprep

df = dprep.smart_read_file('data/crime0-10.csv')
profile = df.get_profile()
profile
# Out:
# ColumnProfile
#     name: Location
#     type: FieldType.STRING
#
#     min:
#     max: (42.008124017, -87.65955018)
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: X Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1129230.0
#     max: 1172409.0
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: 1149945.5
#     median: 1160997.0
#     upper_quartile: 1167630.75
#     std: 14052.038898125928
#     mean: 1157453.7777777778
#
# ColumnProfile
#     name: Description
#     type: FieldType.STRING
#
#     min: $500 AND UNDER
#     max: TO VEHICLE
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: IUCR
#     type: FieldType.DECIMAL
#
#     min: 460.0
#     max: 1811.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 610.0
#     median: 975.0
#     upper_quartile: 1320.0
#     std: 435.0555647781608
#     mean: 1008.7
#
# ColumnProfile
#     name: Y Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1826485.0
#     max: 1946271.0
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: 1876206.25
#     median: 1901632.0
#     upper_quartile: 1932624.25
#     std: 37733.23942825478
#     mean: 1898273.3333333333
#
# ColumnProfile
#     name: Primary Type
#     type: FieldType.STRING
#
#     min: ARSON
#     max: THEFT
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Latitude
#     type: FieldType.DECIMAL
#
#     min: 41.6793109
#     max: 42.008124017
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: 41.81602052575
#     median: 41.885610142
#     upper_quartile: 41.9709022135
#     std: 0.10364520556300641
#     mean: 41.87661278344444
#
# ColumnProfile
#     name: FBI Code
#     type: FieldType.STRING
#
#     min: 05
#     max: 18
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Community Area
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 63.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 10.0
#     median: 28.5
#     upper_quartile: 53.0
#     std: 23.281132083966863
#     mean: 32.3
#
# ColumnProfile
#     name: Ward
#     type: FieldType.DECIMAL
#
#     min: 9.0
#     max: 49.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 16.0
#     median: 30.5
#     upper_quartile: 41.0
#     std: 14.167647024902273
#     mean: 29.5
#
# ColumnProfile
#     name: Beat
#     type: FieldType.DECIMAL
#
#     min: 524.0
#     max: 2431.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 824.0
#     median: 1118.0
#     upper_quartile: 1613.0
#     std: 633.1475516988296
#     mean: 1263.3999999999999
#
# ColumnProfile
#     name: Location Description
#     type: FieldType.STRING
#
#     min: ALLEY
#     max: VEHICLE NON-COMMERCIAL
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: ID
#     type: FieldType.DECIMAL
#
#     min: 10139697.0
#     max: 10140868.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 10139762.0
#     median: 10139830.5
#     upper_quartile: 10140379.0
#     std: 409.8056585475928
#     mean: 10140062.299999999
#
# ColumnProfile
#     name: District
#     type: FieldType.DECIMAL
#
#     min: 5.0
#     max: 24.0
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: 8.75
#     median: 12.0
#     upper_quartile: 17.0
#     std: 6.098724821177329
#     mean: 13.222222222222221
#
# ColumnProfile
#     name: Year
#     type: FieldType.DECIMAL
#
#     min: 2015.0
#     max: 2015.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 2015.0
#     median: 2015.0
#     upper_quartile: 2015.0
#     std: 0.0
#     mean: 2015.0
#
# ColumnProfile
#     name: Case Number
#     type: FieldType.STRING
#
#     min: HY329177
#     max: HY330421
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Date
#     type: FieldType.DATE
#
#     min: 2015-07-05 22:10:00+00:00
#     max: 2015-07-05 23:50:00+00:00
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Arrest
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Updated On
#     type: FieldType.DATE
#
#     min: 2015-07-12 12:42:46+00:00
#     max: 2015-07-12 12:42:46+00:00
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Block
#     type: FieldType.STRING
#
#     min: 011XX W MORSE AVE
#     max: 121XX S FRONT AVE
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Longitude
#     type: FieldType.DECIMAL
#
#     min: -87.800174996
#     max: -87.644545209
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: -87.72499244275
#     median: -87.685233078
#     upper_quartile: -87.65891481025
#     std: 0.05125709218559632
#     mean: -87.6973696417778
#
# ColumnProfile
#     name: Domestic
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0

# %%
print(str(profile))
# Out:
# ColumnProfile
#     name: Location
#     type: FieldType.STRING
#
#     min:
#     max: (42.008124017, -87.65955018)
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: X Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1129230.0
#     max: 1172409.0
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: 1149945.5
#     median: 1160997.0
#     upper_quartile: 1167630.75
#     std: 14052.038898125928
#     mean: 1157453.7777777778
#
# ColumnProfile
#     name: Description
#     type: FieldType.STRING
#
#     min: $500 AND UNDER
#     max: TO VEHICLE
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: IUCR
#     type: FieldType.DECIMAL
#
#     min: 460.0
#     max: 1811.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 610.0
#     median: 975.0
#     upper_quartile: 1320.0
#     std: 435.0555647781608
#     mean: 1008.7
#
# ColumnProfile
#     name: Y Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1826485.0
#     max: 1946271.0
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: 1876206.25
#     median: 1901632.0
#     upper_quartile: 1932624.25
#     std: 37733.23942825478
#     mean: 1898273.3333333333
#
# ColumnProfile
#     name: Primary Type
#     type: FieldType.STRING
#
#     min: ARSON
#     max: THEFT
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Latitude
#     type: FieldType.DECIMAL
#
#     min: 41.6793109
#     max: 42.008124017
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: 41.81602052575
#     median: 41.885610142
#     upper_quartile: 41.9709022135
#     std: 0.10364520556300641
#     mean: 41.87661278344444
#
# ColumnProfile
#     name: FBI Code
#     type: FieldType.STRING
#
#     min: 05
#     max: 18
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Community Area
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 63.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 10.0
#     median: 28.5
#     upper_quartile: 53.0
#     std: 23.281132083966863
#     mean: 32.3
#
# ColumnProfile
#     name: Ward
#     type: FieldType.DECIMAL
#
#     min: 9.0
#     max: 49.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 16.0
#     median: 30.5
#     upper_quartile: 41.0
#     std: 14.167647024902273
#     mean: 29.5
#
# ColumnProfile
#     name: Beat
#     type: FieldType.DECIMAL
#
#     min: 524.0
#     max: 2431.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 824.0
#     median: 1118.0
#     upper_quartile: 1613.0
#     std: 633.1475516988296
#     mean: 1263.3999999999999
#
# ColumnProfile
#     name: Location Description
#     type: FieldType.STRING
#
#     min: ALLEY
#     max: VEHICLE NON-COMMERCIAL
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: ID
#     type: FieldType.DECIMAL
#
#     min: 10139697.0
#     max: 10140868.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 10139762.0
#     median: 10139830.5
#     upper_quartile: 10140379.0
#     std: 409.8056585475928
#     mean: 10140062.299999999
#
# ColumnProfile
#     name: District
#     type: FieldType.DECIMAL
#
#     min: 5.0
#     max: 24.0
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: 8.75
#     median: 12.0
#     upper_quartile: 17.0
#     std: 6.098724821177329
#     mean: 13.222222222222221
#
# ColumnProfile
#     name: Year
#     type: FieldType.DECIMAL
#
#     min: 2015.0
#     max: 2015.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 2015.0
#     median: 2015.0
#     upper_quartile: 2015.0
#     std: 0.0
#     mean: 2015.0
#
# ColumnProfile
#     name: Case Number
#     type: FieldType.STRING
#
#     min: HY329177
#     max: HY330421
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Date
#     type: FieldType.DATE
#
#     min: 2015-07-05 22:10:00+00:00
#     max: 2015-07-05 23:50:00+00:00
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Arrest
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Updated On
#     type: FieldType.DATE
#
#     min: 2015-07-12 12:42:46+00:00
#     max: 2015-07-12 12:42:46+00:00
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Block
#     type: FieldType.STRING
#
#     min: 011XX W MORSE AVE
#     max: 121XX S FRONT AVE
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: Longitude
#     type: FieldType.DECIMAL
#
#     min: -87.800174996
#     max: -87.644545209
#     count: 10.0
#     missing_count: 1.0
#     error_count: 0.0
#
#     lower_quartile: -87.72499244275
#     median: -87.685233078
#     upper_quartile: -87.65891481025
#     std: 0.05125709218559632
#     mean: -87.6973696417778
#
# ColumnProfile
#     name: Domestic
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0

# %% [markdown]
# A DataProfile contains a collection of ColumnProfiles, indexed by column name. Each ColumnProfile has attributes for the calculated column statistics.

# %%
profile.columns['ID']
# Out:
# ColumnProfile
#     name: ID
#     type: FieldType.DECIMAL
#
#     min: 10139697.0
#     max: 10140868.0
#     count: 10.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 10139762.0
#     median: 10139830.5
#     upper_quartile: 10140379.0
#     std: 409.8056585475928
#     mean: 10140062.299999999

# %% [markdown]
# We can also extract a specific attribute across all columns by using a dict comprehension.

# %%
column_types = { c.name: c.type for c in profile.columns.values() }
column_types
# Out:
# {'Arrest': <FieldType.BOOLEAN: 1>,
#  'Beat': <FieldType.DECIMAL: 3>,
#  'Block': <FieldType.STRING: 0>,
#  'Case Number': <FieldType.STRING: 0>,
#  'Community Area': <FieldType.DECIMAL: 3>,
#  'Date': <FieldType.DATE: 4>,
#  'Description': <FieldType.STRING: 0>,
#  'District': <FieldType.DECIMAL: 3>,
#  'Domestic': <FieldType.BOOLEAN: 1>,
#  'FBI Code': <FieldType.STRING: 0>,
#  'ID': <FieldType.DECIMAL: 3>,
#  'IUCR': <FieldType.DECIMAL: 3>,
#  'Latitude': <FieldType.DECIMAL: 3>,
#  'Location': <FieldType.STRING: 0>,
#  'Location Description': <FieldType.STRING: 0>,
#  'Longitude': <FieldType.DECIMAL: 3>,
#  'Primary Type': <FieldType.STRING: 0>,
#  'Updated On': <FieldType.DATE: 4>,
#  'Ward': <FieldType.DECIMAL: 3>,
#  'X Coordinate': <FieldType.DECIMAL: 3>,
#  'Y Coordinate': <FieldType.DECIMAL: 3>,
#  'Year': <FieldType.DECIMAL: 3>}

# %% [markdown]
# A ColumnProfile may also contain a summary of the most common three values with their respective counts. (This is only available if the column has fewer than a thousand unique values.)

# %%
profile.columns['Primary Type'].value_counts
# Out:
# [ValueCountEntry(value='CRIMINAL DAMAGE', count=3),
#  ValueCountEntry(value='BATTERY', count=2),
#  ValueCountEntry(value='NARCOTICS', count=1)]

# %% [markdown]
# Numeric ColumnProfiles include an estimated histogram of the data.

# %%
profile.columns['District'].histogram
# Out:
# [HistogramBucket(lower_bound=5.0, upper_bound=6.9, count=1.1333333333333335),
#  HistogramBucket(lower_bound=6.9, upper_bound=8.8, count=1.1666666666666672),
#  HistogramBucket(lower_bound=8.8, upper_bound=10.7, count=1.549999999999999),
#  HistogramBucket(lower_bound=10.7, upper_bound=12.6, count=0.8499999999999996),
#  HistogramBucket(lower_bound=12.6, upper_bound=14.5, count=0.6333333333333337),
#  HistogramBucket(lower_bound=14.5, upper_bound=16.4, count=1.2666666666666666),
#  HistogramBucket(lower_bound=16.4, upper_bound=18.299999999999997, count=0.47499999999999964),
#  HistogramBucket(lower_bound=18.299999999999997, upper_bound=20.2, count=0.4750000000000014),
#  HistogramBucket(lower_bound=20.2, upper_bound=22.099999999999998, count=0.47499999999999787),
#  HistogramBucket(lower_bound=22.099999999999998, upper_bound=24.0, count=0.9750000000000014)]
